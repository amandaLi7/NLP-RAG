# %%
import pandas as pd
import os

# %%
info = pd.read_csv('../data/paper_logs/combined_json_data.csv')
# display(info.head(60))

# %%
print(info.columns)

cols_to_keep = ['paperId', 'title', 'profName']

info = info[cols_to_keep]

print(info.columns)
# Out:
# Index(['profName', 'authorId', 'authorName', 'authorUrl', 'authorHIndex',
#        'authorAffiliations', 'authorPaperCount', 'authorCitationCount',
#        'paperId', 'externalIds', 'url', 'title', 'abstract', 'venue', 'year',
#        'referenceCount', 'citationCount', 'influentialCitationCount',
#        'isOpenAccess', 'openAccessPdf', 'fieldsOfStudy', 'journal', 'authors',
#        'tldr'],
#       dtype='object')
# Index(['paperId', 'title', 'profName'], dtype='object')

# %%
max_md_len = 0
max_md_text = ''
for paperId in info['paperId'].values[:1]:
    cleaned_paper_file_path = f'../data/cleaned_papers/{paperId}.txt'
    if os.path.exists(cleaned_paper_file_path):
        print(f'File {paperId}.txt exists')
        text_block = ''
        for feat in info.columns:
            text_block += f'## {feat.upper()}\n'
            text_block += f'{info[info["paperId"] == paperId][feat].values[0]}\n'
        if len(text_block) > max_md_len:
            max_md_len = len(text_block)
            max_md_text = text_block

print(max_md_len)
print(max_md_text)

        # # write to top of file
        # with open(cleaned_paper_file_path, "r+") as f:
        #     prev_content = f.read()  # Read existing content
        #     f.seek(0)  # Move to start
        #     f.write(text_block + prev_content)  # Prepend with new content
        #     f.close()
# Out:
# File 2107b867cb8f8afa30a9a940288d7c8b657f8aa5.txt exists
# 177
# ## PAPERID
# 2107b867cb8f8afa30a9a940288d7c8b657f8aa5
# ## TITLE
# Zero-Shot and Few-Shot Stance Detection on Varied Topics via Conditional Generation
# ## PROFNAME
# Alexander Hauptmann

# %%
for paperId in info['paperId'].values[1:]:
    cleaned_paper_file_path = f'data/cleaned_papers/{paperId}.txt'
    if os.path.exists(cleaned_paper_file_path):
        print(f'File {paperId}.txt exists')
        text_block = f'\n '
        for feat in info.columns:
            text_block += f'## {feat.upper()}\n '
            text_block += f'{info[info["paperId"] == paperId][feat].values[0]}\n '

        # Add metadata every K characters
        K = 2000
        new_txt = ''
        with open(cleaned_paper_file_path, "r+") as f:
            prev_content = f.read()
            for i in range(0, len(prev_content), K):
                new_txt += text_block + prev_content[i:i+K]
            f.close()
    annotated_paper_file_path = f'data/annotated_papers/{paperId}.txt'
    with open(annotated_paper_file_path, "w") as f:
        f.write(new_txt)
        f.close()
# Out:
# File 376f494126d1ea4f571ea0263c43ac2b6331800a.txt exists
# File 405e3910e06c9efe7e660b8697bcb4bab4e92f48.txt exists
# File 8ccda6de0223bcd897d5dc0efc8f33222a899d0d.txt exists
# File 10127fa44054eb985ede206113b96aac3a96fd80.txt exists
# File 5579d38636b898c6a67ad67a16a80dd83be0f8d4.txt exists
# File 5c920b2326282d93ad2ac3d1cb8f746bd7ab6f50.txt exists
# File 9364720b2ab9ac67bc08e2b0b49aadded3d4e2e5.txt exists
# File 9e8f125ef479af7e95ee5b8949b24e750c7df367.txt exists
# File bcefc74b20649fd41ea05d87a3fa512d2559fc8d.txt exists
# File 161bf3f0705ef8e088f53b383363338daac9af44.txt exists
# File 465ec2212d865e875e64638b3dd1ecaac21c5ddd.txt exists
# File 610d9958390ab83515d0d81e19f8e5264faf8e9b.txt exists
# File 7e13fcb7b7bae202fb9087e87abaa71a4b19a3e3.txt exists
# File d24d60719e90e69749a75c160cb760d1d9fca44a.txt exists
# File f524f119afc13cc07ca15998c10b9509e9e9b0b5.txt exists
# File f7e995c3cae465963ecaa8c9b4ce8b9b4323a71b.txt exists
# File f3e237e794bc4cd8df7f3e31d0caa2f7ee8cd06b.txt exists
# File f547c7ec86cbc0989e87f0e23f7e0b2cfc5259c3.txt exists
# File 72cce47fd053bf916314d89a8174726c58c05e02.txt exists
# File 06a8f2e3c4266196b008851f1ec7ef9f340809da.txt exists
# File 2670612b5e11297cd9b98f4d7ff796725f77fe35.txt exists
# File 4b8d3ede673ddeab9dfb5184da6b748d7a526754.txt exists
# File 9799c17fd287bb9e8d231fe032c6dbf9c0c9d675.txt exists
# File 283dbaa4da4beafa5e5719095bcc88e63d17815e.txt exists
# File 3859f18277f0c5876a53411b07f80d65254c52e5.txt exists
# File 4d35540aaf993c8fa7e1fa5fc6a990f1eb830263.txt exists
# File d898963243ad4b177b799f197a7732395e165cf6.txt exists
# File f1ebdd8c99aa33284e3604c28b72efa9dc46047c.txt exists
# File 078f86c6a691806cc71bbef1e734f75690db0ffc.txt exists
# File 0a8d38686b18f28aae1222529e6b9e8a60cab1c2.txt exists
# File 100da279ee981960884a12dfc5a0697c24ed315a.txt exists
# File 11c50900f50036fb3247be7c83849a8774a4ba60.txt exists
# File 3bd320ddb25886417ae90011b00f13f5d558097b.txt exists
# File 4e6a004e4f9a3b489004a2efb5b25b0bcd0f48b5.txt exists
# File 5a3307b2e64bbcaff1202e261b8a83f7d03418a8.txt exists
# File 611f9ee6eef0936462cd78f371798d0699951c59.txt exists
# File 7333be530df311b3148e9857ce9f481975cf0a9b.txt exists
# File 740488982dee323d559f2dae70b1f4b3aa5f7171.txt exists
# File 74664618ad3b44eb191ba96fdff5b93f27a29ced.txt exists
# File 8665c864d71df1e918d2010778fc06712f4e5550.txt exists
# File a6e3a10a6286967413e3406374bbeea533640030.txt exists
# File ac856b6b7b3f32fb34320b7170526d3ab15ba5f3.txt exists
# File dc157eba8bdb4cfe6ee65566d8295939ac5b4b37.txt exists
# File e146e5221c124d93f69516c5ae7e1b7b1822848e.txt exists
# File feecd2cfb7871a818ba514e8b4b3f9da482f17bc.txt exists
# File 0c0d8ea1c1745e7b56bc3b1513a715ae3df30c44.txt exists
# File 117e1323677cb5d78ece0fd07b5cfa81618f4866.txt exists
# File 15d85036b15388bcb0199c83c01ba833e6095a31.txt exists
# File 27ca2d927421035e10b48c96a96db32224f1f8e6.txt exists
# File 159100c8323fc558e4073a3a006f3f243aca3a60.txt exists
# File 275da3802142fc42f6fab2ce2104223b2e0ef40d.txt exists
# File 105759bdb5e3bddc1d3244df2eff2d5c997a1d84.txt exists
# File 24811cadf16519910f643b6084107164e6ca4219.txt exists
# File 38aaf8a29df6deeff0bf64cc835d242a25b10337.txt exists
# File a57b90cfc2eab46b773e65240d4ff910f05f989e.txt exists
# File b9e8b62bcc019f47a0a015568f70039b3b7c1196.txt exists
# File e0401ca2d4fd6d0ed55130a4a24b33ed90111479.txt exists
# File 19f59c14b3d79e3203c696128a135d33eb35e468.txt exists
# File 1bf21dabbdfc81fd4f9e92b1201ecce744cabb6a.txt exists
# File 2b2d9ee18507aa89a7f1ecba0bf68844c7d9aa75.txt exists
# File 3e4085e5869f1b7959707a1e1d7d273b6057eb4e.txt exists
# File 6fb5c0eff3696ef252aca9638e10176ecce7cecb.txt exists
# File e41482f4ee984f17382f6cdd900df094d928be06.txt exists
# File 03fb535de5cfcf435705a079334ac60f501226ab.txt exists
# File 1567bcac0ab09269c9d0ff33c9a406132417fab9.txt exists
# File 2e965b5d97c2d6fb4af284307735be39283792ba.txt exists
# File 8724579d3f126e753a0451d98ff57b165f722e72.txt exists
# File 11a571eaab42a6ffb1d938635a093315e392756d.txt exists
# File 17fbffb05fa14e21d1c506fd5f0f568b955fe983.txt exists
# File 659be1ff350634f50cc066d258ee6a45e697e552.txt exists
# File 7a08051aac75a809737096e39820bf836908d4e1.txt exists
# File bf42c0462d1415cdde877c90d58da11545407b8a.txt exists
# File c5c6d006e399386c99068daba138021a62d6cc17.txt exists
# File db14d05b18ec852f8afcd6d2d10bbd9eeaef8325.txt exists
# File 075b751201f549daeba9840f78768f4ceb507e17.txt exists
# File 8cc1cd002bfc36a8cba8bcbe63d32eacc656097f.txt exists
# File a0a79dad89857a96f8f71b14238e5237cbfc4787.txt exists
# File dcb4f2b9b0e6da0d629878d1ad0469aee3df2020.txt exists
# File 1433b8d43d446fcc7f3e1370b22f744a4dd7c8e4.txt exists
# File 45e50baac4d341f0cf1a40af096bfa9c3f555235.txt exists
# File 667ba2e8f1933b6c32e9672012526904b4c5dc31.txt exists
# File 71debf888acd57bb1baa4c146f31e58c66ea51af.txt exists
# File 84d20ad9f42d80dfd5130a6362d5422be8a6bdc3.txt exists
# File 88549b4f48b9709acdfb8b9e41656b6d133c5390.txt exists
# File a815c3209e7baff4466dbf6e129129511f842b7e.txt exists
# File b13da1161d65a8de7a96051b5bc68d5eaa8eb37b.txt exists
# File b777aa86b5a1d49ce8eababc5c2ee56d3562801e.txt exists
# File ba31ccac5fe5ea151727e8427e78bb300c35f899.txt exists
# File 0f008e07d601e8f21d1df5db3d36e85484840083.txt exists
# File 3a30217c4115777fb30c182c97cc77d34d065556.txt exists
# File 444737639aeea4e1e616509e368afb0bae8f89d6.txt exists
# File 61354e45bca908ad08f24e44bd507b4e1c958e6f.txt exists
# File 55704caaf3d31e1795a1ca0c3bed9e77ae3a3c95.txt exists
# File 567f6bc975deb3d728feec9bfcf7d4036ceabb12.txt exists
# File 5e1ba2d4416333dd6f6a31a4ff4221b40dfb74b1.txt exists
# File 03c7f61b0c6bc4c480ed6da4e9d7dda104ddfec3.txt exists
# File 11a571eaab42a6ffb1d938635a093315e392756d.txt exists
# File 17605c43ca3eb982c99642052ddc21a93d116594.txt exists
# File 1786a2f9140ed7211b21302977de64e948b92308.txt exists
# File 31366ff634fc905affd78dbd8ddc9a872c006a87.txt exists
# File 405f1a5602867c66e015491c26d2be5504eed458.txt exists
# File 43c0f77f116f986b53eb04f5c9b33f10132ded55.txt exists
# File 4d74a5048b884e8bb3842240abf98915c619c8f8.txt exists
# File 5ea8eedcb31859c5730dd1da3804e1be529ffabb.txt exists
# File 659be1ff350634f50cc066d258ee6a45e697e552.txt exists
# File 74b05bba46db21e589a2cc0f916f81069b0368ef.txt exists
# File 7a5b44ea10a51708e18786595c8d70b18950da11.txt exists
# File 88884b8806262a4095036041e3567d450dba39f7.txt exists
# File 8e8a1489bf4d782d2435cdeb93f7d1f165747c63.txt exists
# File 9bce3661f01825ad56dc9d2b3d254fd9e3792360.txt exists
# File b4987da792dd45a84232cfb06d71b1c2ec488f38.txt exists
# File c432aff446d55e72a28394a1508e760cc9a25c08.txt exists
# File c5207241406586f4263b235667e004b71ea68953.txt exists
# File cc1705fe421c70d85254b557634bd4669fdd49b0.txt exists
# File d5dd7230cccace7e77095d3b5fd8394850f59170.txt exists
# File d6ae4c0679bdceb029f652efd2a854ac5ade772f.txt exists
# File dbc368bc8b49347dd27679894524fa62f88492c9.txt exists
# File e41482f4ee984f17382f6cdd900df094d928be06.txt exists
# File e69684fb06a7b1fe621d7ef0c97fc2ca0e122c43.txt exists
# File e7b3b692b0816821aafc0d354749bc3802cbf6ac.txt exists
# File f640e89fcede075b4bde3b2fa0dc78f591589ba3.txt exists
# File fd80f7f3673fc6ca02f192d5d73426f11a4be659.txt exists
# File 88884b8806262a4095036041e3567d450dba39f7.txt exists
# File ac9ee72a5cd611e9143e385f668af662583721ee.txt exists
# File 0e84679cf0945a2868245ba2be68c90453e48f2e.txt exists
# File 3f261fb980858e39129af5bc8a6c8565d7bb8329.txt exists
# File 8ab27849799286459465d2262f926354093b20a9.txt exists
# File d757a58200254625c3326a32a1da6fa8eaa2eff3.txt exists
# File 24bff26f19051b1413d1e343322c1ae4bba05428.txt exists
# File 74fedee9d809ec766a2089a89435fa7dd1346693.txt exists
# File b3efaa75beada858414a5ba2346dec317203633c.txt exists
# File 145c90515c04f40c4e88a177adeb4fcd6c1009b0.txt exists
# File 17b16a2b31797a8fd4bcd5fd952294357db39b25.txt exists
# File 2c331e93a1648ab6492787bb81287b9c8100d9f3.txt exists
# File a84e98cb2d0a3624523f15eaa10c6321704526ab.txt exists
# File bdbf385090f6c988c419c9db1673a2c03c94b7a1.txt exists
# File c8b27d092e0f9e286bb354bb892984a30126c702.txt exists
# File dfd8944d39b378489b878d6e105d040fa0e524db.txt exists
# File 52a97ad16605c18e23c9750a388a26a9cdf12200.txt exists
# File 0a425c0d87c674b142104a07e17c5084b3ad28ca.txt exists
# File 40fb36ee67fdde99b196b4d1772de114aa821698.txt exists
# File 47a4ac301820c3ea7da4efb8e2466cc6468ad631.txt exists
# File 7dab13685363176edc5cc7882d0890811d2cb584.txt exists
# File 8d0c37eee7162f33178979b4183f0211e2dcae0d.txt exists
# File a988c09b7e76e86a93edcbf3f284dd028b0fb406.txt exists
# File dcb4f2b9b0e6da0d629878d1ad0469aee3df2020.txt exists
# File e1b2a35a000ca296c32284b323c7e36a28fe0693.txt exists
# File f891e9eeedbf20cdc54429ffcc0402a10f48494e.txt exists
# File 2a3213cb3c755f036d5dfec7261d726a819c78c1.txt exists
# File 376f494126d1ea4f571ea0263c43ac2b6331800a.txt exists
# File 861370f7c2d18bed09905fde334a19cc96e83e14.txt exists
# File 8670133f0839a83c47c5bd2a506d0254d73f1a2c.txt exists
# File 985f0c89c5a607742ec43c1fdc2cbfe54541cbad.txt exists
# File c5202ab27294d5c1eb4d2f0ca7e82afef91888f0.txt exists
# File bc603b3878dd8638254f3746b892100cad687ea5.txt exists
# File de52a2f746c5cf145ee2af3a978ee1942eec1a57.txt exists
# File 14ddefae2be4b5bb50b9fcb4a085e45fbecb5c5c.txt exists
# File 185ace5661963e2e1eb998e739e4110272a6bb43.txt exists
# File 27553f8bd9cbee90f6e65b9cdecadff0e7cc55ee.txt exists
# File 57d65e85c62aef04dfb2a48380e415fbb790e5ee.txt exists
# File 85a5ffc509fa50c96b415e09ae87fb6e5f435b37.txt exists
# File 9d2dc57903e99f33b9cf727c3903718751d82663.txt exists
# File a5731b32060909bfc8848fa5f7e1e14ca3b53240.txt exists
# File a66ff335f5934fe7503a99d3eb3abed493994df1.txt exists
# File a89c30ceca55783a1b2ff843eb6a4793e4a54b66.txt exists
# File c2850c897a179c07a25023029306600e0ea82f75.txt exists
# File d655f652d02251b45db43181c5e3c73dfc59cd51.txt exists
# File ddcd2bcc809bd0c2755a4a9487473d61ac327c50.txt exists
# File ea0585ed23e25d5f8682eb91f20c6ddbeb6a27b4.txt exists
# File 2386c6a7c40b5129960f2eb3c6be27db65b04c1f.txt exists
# File 2605bc92935ca67829e9542030be0e44ae81c22e.txt exists
# File 604cc00ff6a4d57d97856b49be4df89452cf30a8.txt exists
# File 78ee30f94bfa9c08306cd2f5bf92e98240aa692d.txt exists
# File e2be92ff1ae2abdc05c1929d6d02623c58f37097.txt exists
# File ee866d0dd47351542e4924f14203a767dd03194a.txt exists
# File f19180afd6cae7c241fa461eed122e4c04a14217.txt exists
# File d6ae4c0679bdceb029f652efd2a854ac5ade772f.txt exists
# File dbc368bc8b49347dd27679894524fa62f88492c9.txt exists
# File e80f1b4c254a5c135f5f3416ba3a863f8ec4e06c.txt exists
# File ebb3d299213bae89b5d302cc3dfc36573ec83956.txt exists
# File 1109a51ff68d8c7a09d651d706028e9e380f2af8.txt exists
# File 5315883bd39a4e4af6332e344bb32d29613b3c97.txt exists
# File ff28f812113a7082f7d285ed3bf6dcbed49d0320.txt exists
# File 45f7ab2dd1bd86703f3fc0f713d35851ae15b038.txt exists
# File c5849f406e8263806a84e1a407ec0e0fe131bd5c.txt exists
# File 0a94fbb5e1c93513523f00e75d672ef4553861f9.txt exists
# File 4286d07449447f3bfffc1eeb2ee0de9b00dfadfd.txt exists
# File 5e2f8088647e357bb6440d271ed1fcc4d5ed7e7c.txt exists
# File 99bfe503743c5ec8e16e50ab8438159cdb533a89.txt exists
# File c218cd1772999517b137bbbc9872c4f67e540b7f.txt exists
# File f727f928e7e179307d8d4a1da2387393f2bd7915.txt exists
# File 3f165dae2310a5d8aa7294ffdc45573a51c957b8.txt exists
# File 88efd1663016c4170674c8f30067e7096b172598.txt exists
# File d07e77f0477c3568d64086ef4d50ea1fcff63b8c.txt exists
# File 3bd320ddb25886417ae90011b00f13f5d558097b.txt exists
# File 5a3307b2e64bbcaff1202e261b8a83f7d03418a8.txt exists
# File 63a4150c9ad87c003de43b32828c8ceec6bb4468.txt exists
# File 721b39472c801124b5e3102edffe9d6f0754e1c2.txt exists
# File 8665c864d71df1e918d2010778fc06712f4e5550.txt exists
# File a6e3a10a6286967413e3406374bbeea533640030.txt exists
# File ad22af138fa1d1490cda0301abf8159a7c30c5a2.txt exists
# File 61c7e06e7d6760ecf2f5d20f86711287d131d8ea.txt exists
# File d486295e298f682b2f98e21106af659d88d396a5.txt exists
# File 13922d438c437cea443b6c4747c54a29a8bdd742.txt exists
# File 3aaf6a2cbad5850ad81ab5c163599cb3d523436f.txt exists
# File ca991e0283a1c30a46eb585d9eb499fc0ec8ecc2.txt exists
# File 01a819f7155bb87c32f1e4c13d9439c080e6aa97.txt exists
# File 0534fd0ed04acaa60f820b730bf3c4816767fa43.txt exists
# File 06353e1b7e7c8dc701ac76dcd4db5061b24468c9.txt exists
# File 090b284b2f8fc93ac3e7a92fc9f91bf4965ba75c.txt exists
# File 1028bf42a4c792acefd3be9da45e58f2b1620fe3.txt exists
# File 10e8dc07ea256c6a88d7043cf135417402ed38f4.txt exists
# File 14f5fd91d75bc10d9fff53dfe7ee73484fc4273b.txt exists
# File 16fbcf340648b302ad8d4e6ed34c7ab5ad346db9.txt exists
# File 25c399a231364f4a77d1dc4b59927585e63f5f11.txt exists
# File 331af9b7193e563b021e8e6892e7cb3030decd38.txt exists
# File 3b93dd5f2d2512a4b58f6c776af59f74a90764a5.txt exists
# File 3bd320ddb25886417ae90011b00f13f5d558097b.txt exists
# File 48c6318dbcf9908cabe0023b8817566f34d0b466.txt exists
# File 4b8d3ede673ddeab9dfb5184da6b748d7a526754.txt exists
# File 4d35540aaf993c8fa7e1fa5fc6a990f1eb830263.txt exists
# File 52d2c8d36c4ace01d8c440a44e1a7fdea04ec482.txt exists
# File 611f9ee6eef0936462cd78f371798d0699951c59.txt exists
# File 659be1ff350634f50cc066d258ee6a45e697e552.txt exists
# File 6c33625c7b0ffc37955921a145531d9d4eaee713.txt exists
# File 786294f4008732a5dac9895a8507bc4c80450075.txt exists
# File 7d4ad68dedff8c81e0fd9c08ea76b220a7e05d69.txt exists
# File 7f995454efda9f660d2258f59f6e19a2125e688e.txt exists
# File 8402d64fde12cafaf8a1daa60de0acd1abedbffb.txt exists
# File 8bc617c9139648d7a92991d70c671230bac7b2e2.txt exists
# File 8f0a24d1678e4d0e584b0932196cd257d5c53c7d.txt exists
# File 91a06713cbccbfb1b5e1b9f7b62a1fba348616c3.txt exists
# File 95aac8fe824bd0c83de594af0bf9d259e2416f53.txt exists
# File 9dcfb422f6057725b1585caf820e128c91d6dbb3.txt exists
# File a5ab124e57d1f26436821588aacd7d75b831259c.txt exists
# File b4855ff933fb80846638469a1b43c1766df85d78.txt exists
# File b524ec331cd9708b125fad70d95d36189fa0d7b6.txt exists
# File bb4c59fc93d5be6b3d85dfde9d08e3dab80db9b7.txt exists
# File bc3690edd40cc9946f8162727b357b926d1127bc.txt exists
# File c2745e86ecc9bec372690cced53ccfdf44f407f8.txt exists
# File c823c04a6488673f936d72906130f170017288d0.txt exists
# File d43338451cd8676548811e1ff8f9c92ea987c5bd.txt exists
# File d4d5fe4a35e9de845877015075f727415e83d18f.txt exists
# File d8728d62b238b09630309c1df723036db84bac10.txt exists
# File dab8e7dc79085774eea58bcb9ea2ed0ee20377eb.txt exists
# File dd5d797b837005fac464bb19b9396bddba61c0d8.txt exists
# File e146e5221c124d93f69516c5ae7e1b7b1822848e.txt exists
# File e25f6a60211aa74ecfde8001a5939ff206102de4.txt exists
# File e2826002978af39afce7529f172ffdc222342651.txt exists
# File e4f2d75856ce149b994f079ae50fd33ca47245d3.txt exists
# File e64d4b29a4a6ccac3673b4cedbefa1e54e774c20.txt exists
# File ef567580e167c3e7c546345df93d644be5d4f66f.txt exists
# File ef8b095292a8e38e9b8f56c54cbf3c67c3ed425d.txt exists
# File f53b6f5a85f2d74deb32022795b5dab0aa753cf4.txt exists
# File f7e995c3cae465963ecaa8c9b4ce8b9b4323a71b.txt exists
# File fa5ebb425c57f6c4f1c36a7200ef1da867346e8c.txt exists
# File fa75ef55e04e3b25b8af56435478c2fd17403ce8.txt exists
# File 444737639aeea4e1e616509e368afb0bae8f89d6.txt exists
# File ff77105b2c345f54e1a87f4fbb3a701201f0c1a8.txt exists
# File 1527d3b661154ff7310fa2759b6dd0ddfd559492.txt exists
# File 15b08595533bfc640f4dd470ca7a2273badec20a.txt exists
# File 464edfd902f652d3ab6a25dbb6d9fa47cc3246a9.txt exists
# File 55324ec5662bbea2e226ce3d8e6258a62836e940.txt exists
# File 924036c17537adc8574a1476bf13d9d17a6eebae.txt exists
# File c70c11d6de5eec2677eaa87fd3112068db6fedfe.txt exists
# File cb754310302086dfbbcd098263200e2a03f65874.txt exists
# File d9dc309f719233be9f2a6b6910072e537f96eec8.txt exists
# File 61678a9f1d8291bb0f3d704a439ac8cd64fa6482.txt exists
# File 8874cd8cb99d00e133fba10454e5e5e64f38ca85.txt exists
# File 2ca8e50ffd6e2e67f3fe2fbf1af57dbedb4cf493.txt exists
# File 646cca9de110726000a6e44560743b241a4d7f91.txt exists
# File 83b8e18488d8f31dd017ec0b26531cef4b635b36.txt exists
# File c67099476f2b505dfd5a22c817707fad83de9994.txt exists
# File 08a23cb1ae7b0748407146520c0630d7f2b51c4c.txt exists
# File 0a187bee2436f4a2e98dd94d3c2f18b83281efdb.txt exists
# File 16db1c1c00ac219984c28480cb60fd09b1897bf6.txt exists
# File 2bfa8ac40c1ff8e45c298115fcadae062526310e.txt exists
# File 48bd660e0841ca990178cfafec01163ba2bb07ee.txt exists
# File 535047a5e5845b3a05fb566d9733091448410d75.txt exists
# File 5f90d43e6ece5c6ee6e8186e4b57d46c85377713.txt exists
# File 6a42f6362afa3a1a0936f7a6a8927d04a2285cc5.txt exists
# File 844bb298d49ef4a07b5d4929dfdfd170f6a1d5f5.txt exists
# File b946ca9514be9920e5d1eff11f597facb8f7c6b7.txt exists
# File f1a75a847c99ab399454c911235f0d5f7854c5a4.txt exists
# File 02ce4d3f93902a94ec2b57630b77696b7f18c84a.txt exists
# File 1786a2f9140ed7211b21302977de64e948b92308.txt exists
# File 1804dc14b1cf7bbae96bf3215997e9f14425d622.txt exists
# File 3aaf6a2cbad5850ad81ab5c163599cb3d523436f.txt exists
# File 3c92fd24ea2a49aeba4b368abe3ef13cbce40987.txt exists
# File 4ce987d4f8ae0f4680808c318980d42a82b9aa89.txt exists
# File 846f60ef3b98590c7ad1d84727c66a08cc2258c8.txt exists
# File 88884b8806262a4095036041e3567d450dba39f7.txt exists
# File b4a6c010724f0459c9791018e34a982cf96987cf.txt exists
# File e01515c6138bc525f7aec30fc85f2adf028d4156.txt exists
# File fe9fe9f15f24fbbb19b62bcd9a3418511a699b84.txt exists
# File 376f494126d1ea4f571ea0263c43ac2b6331800a.txt exists
# File 3b0c02955e88f5862e61b560c7f70ba8cf235b1d.txt exists
# File 5ce2f1dff23a5620f77f9b11f1e534422ab8ff3f.txt exists
# File 69b8cd15966c4c9c3e44e71769e557f1c87fb3f9.txt exists
# File 8035a247980cb18abf2bb7b9d96e7d4c63622ef2.txt exists
# File b777aa86b5a1d49ce8eababc5c2ee56d3562801e.txt exists
# File e41482f4ee984f17382f6cdd900df094d928be06.txt exists
# File e7b3b692b0816821aafc0d354749bc3802cbf6ac.txt exists
# File 12902f724619344dfeae330043c4b7b1c9d99bd0.txt exists
# File 17605c43ca3eb982c99642052ddc21a93d116594.txt exists
# File 17fbffb05fa14e21d1c506fd5f0f568b955fe983.txt exists
# File 1bc0dc96d745325d89ec5bee1da1541255e6d1eb.txt exists
# File 36f7bc27c9a37eb337c35df4ae86f148e13d4e9a.txt exists
# File 49f1fa0d609ff06564b46270cbc022b7d9d195f4.txt exists
# File 5471114e37448bea2457b74894b1ecb92bbcfdf6.txt exists
# File 663d743272e9ab04f54d9105a3c3a3f6e22dd1dd.txt exists
# File 926dece297434dc535733814efca28759b94ab82.txt exists
# File 984d4a1d41bfc8184fb77b8aa0eb8e96d536d048.txt exists
# File ad454e24bd32408559512b4bac4cd5237794210f.txt exists
# File cb0335107f12d331ace2cbf220eb3c7bdcf653c5.txt exists
# File d7a3f5c612930a3c08f1632b88934252edc66d67.txt exists
# File df2beaae63e4d68ef8e762bcd4704c9f11f856d9.txt exists
# File f9a5af5b21563b9bdd09630a8dec62d515479678.txt exists

# %%
import csv
import requests
import json
import sys
from requests import Session
from typing import Generator, Union
from requests import Session
import subprocess
import pandas as pd
import logging 
import numpy as np
# Out:
# /var/folders/29/2n699yc91qs65qqg0cqgqtlr0000gp/T/ipykernel_70644/1295341610.py:9: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import os
API_KEY = os.environ.get('S2APIKEY')

# %%
base_dir = 'data' # all changes from this file will be under this directory

# %%
# website
lti_faculty = ["Yonatan Bisk", "Ralf Brown", "Jamie Callan", "Justine Cassell", "Mona Diab", "Fernando Diaz",
               "Scott Fahlman", "Robert Frederking", "Daniel Fried", "Anatole Gershman", "Alexander Hauptmann", 
               "Daphne Ippolito", "Lori S Levin", "Lei Li", "Teruko Mitamura", "Louis-Philippe Morency", "David R Mortensen",
               "Graham Neubig", "Eric Nyberg", "Kemal Oflazer", "Bhiksha Ramakrishnan", "Bhiksha Raj", "Carolyn Rosé", "Alexander Rudnicky",
               "Maarten Sap", "Michael Shamos", "Rita Singh", "Emma Strubell", "Alexander Waibel", "Shinji Watanabe", 
               "Sean Welleck", "Eric P. Xing", "Chenyan Xiong", "Yiming Yang"]

affiliated_faculty = ["Jeffrey Bigham", "Matt Gormley", "Ian Lane", "Brian MacWhinney", "Tom Mitchell", "Jack Mostow", 
                      "Raj Reddy", "Roni Rosenfeld", "Norman Sadeh", "Richard Stern", "Rodolfo M Vega"]
adjunct_faculty = ["Malihe Alikhani", "Taylor Berg-Kirkpatrick", "William Cohen", "Christopher Dyer", 
                   "Madhavi Ganapathiraju", "Matthias Grabmair", "Lu Jiang", "Alon Lavie", "Michael Mauldin",
                   "Florian Metze", "Thomas Schaaf", "Ravi Starzl", "Yulia Tsvetkov", "Monika Woszczyna"]

lti_complete_faculty = lti_faculty + affiliated_faculty + adjunct_faculty
expected_length = len(lti_faculty) + len(affiliated_faculty)+ len(adjunct_faculty)
assert len(lti_complete_faculty) == expected_length, "Length does not match the expected value."
lti_complete_faculty.sort()
print(len(lti_complete_faculty))
# Out:
# 59

# %%
author_id_path = 'manual_authorId.csv'
author_df = pd.read_csv(author_id_path)
duplicates = author_df[author_df.duplicated(subset='author_id', keep=False)]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [author_name, author_id]
# Index: []

# %% [markdown]
# ### Fetching author data + paperIds

# %%
def add_paper_id_csv(paper_id, paper_title, author_name, author_id, field, csv_file_path='data/paper_logs/paperId.csv'):
    if not os.path.exists(csv_file_path):
        with open(csv_file_path, 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow(['paper_id', 'paper_title', 'author_name', 'author_id', 'field']) 
    
    with open(csv_file_path, 'r', newline='', encoding='utf-8') as file:
        reader = csv.reader(file)
        existing_data = [row for row in reader]

    # Check if the paper ID already there
    if paper_id not in [row[0] for row in existing_data[1:]]:
        with open(csv_file_path, 'a', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow([paper_id, paper_title, author_name, author_id, field])

# %%
def fetch_paper_json(author_id, 
                    year, 
                    open_access = True,
                    manual=True, #['Computer Science', 'Linguistics']
                    save_raw = False,
                    parent_dir =  'data'):
    if not API_KEY:
        raise EnvironmentError("S2_API_KEY environment variable not set.")
    # Set up the headers with the API key
    headers = {
        "x-api-key": API_KEY
    }
    print("--------------------------------------------------------------------------------------------")

    fields = "authorId,name,url,hIndex,affiliations,paperCount,citationCount"
    fields += ",papers.paperId,papers.title,papers.year,papers.url,papers.abstract,papers.authors"
    fields += ",papers.externalIds,papers.openAccessPdf,papers.fieldsOfStudy"
    fields += ",papers.influentialCitationCount,papers.journal"
    if open_access:
        fields += ",papers.isOpenAccess"
    
    response = requests.get( # following their git modules
        f'https://api.semanticscholar.org/graph/v1/author/{author_id}',
        headers=headers,
        params={'fields': fields}
    )
    
    if response.status_code == 200:
        author_data = response.json()
        name_fetched =  author_data.get("name")

        # Paths for saving jsons 
        raw_data_dir = parent_dir + '/paper_jsons'
        processed_data_dir = parent_dir + '/paper_jsons'
        raw_file_name = f'raw_{name_fetched}_{author_id}.json'
        processed_file_name = f'{name_fetched}_{author_id}.json'
        # If want to save the raw output (not filtered)
        if save_raw:
            os.makedirs(raw_data_dir, exist_ok=True)
            raw_json_file_path = os.path.join(raw_data_dir, raw_file_name)
            with open(raw_json_file_path, 'w') as raw_file:
                json.dump(author_data, raw_file, indent=2)
                print(f"Saved raw data to {raw_json_file_path}")
        
        
        # allowed_fields = ['Computer Science', 'Linguistics'] if not manual else None
        # Filters: Open Access, Year, and optionally by Field if manual is False
        filtered_papers = [{
            "authorId": author_data.get("authorId"),
            "authorName": author_data.get("name"),
            "authorUrl": author_data.get("url"),
            "authorHIndex": author_data.get("hIndex"),
            "authorAffiliations": author_data.get("affiliations", []),
            "authorPaperCount": author_data.get("paperCount"),
            "authorCitationCount": author_data.get("citationCount"),
            **paper,
            } for paper in author_data.get('papers', [])
            if str(paper.get('year')) == str(year) and paper.get('isOpenAccess')]
            # and (manual or any(area in paper.get('fieldsOfStudy', []) for area in allowed_fields))]
        
        print(f"Author: {name_fetched}, id:{author_id}, All: {len(response.json().get('papers', []))}" )
        for paper in filtered_papers:
            paper_id = paper.get('paperId')
            paper_title = paper.get('title')
            paper_authors = name_fetched
            if paper_id:
                add_paper_id_csv(paper_id, paper_title, paper_authors, author_id, paper.get('fieldsOfStudy'))

        print(f"Author: {name_fetched}, id:{author_id}, 2023+OpenAccess+Fields: {len(filtered_papers)}" )
        # Save the processed data
        if len(filtered_papers) > 0:
            os.makedirs(processed_data_dir, exist_ok=True)
            processed_json_file_path = os.path.join(processed_data_dir, processed_file_name)
        else:
            print(f"No OpenAccess CS+L papers found for {name_fetched} in {year}")
            return
        
        with open(processed_json_file_path, 'w') as processed_file:
            json.dump(filtered_papers, processed_file, indent=2)
            print(f"Saved processed data to {processed_json_file_path}")
    else:
        print(f"Error fetching author data: {response.status_code}")
        if response.text:
            print(json.dumps(response.json(), indent=2))
        else:
            print("No additional error information is provided.")

# %%
authors = author_df['author_name'].tolist()
authorId = author_df['author_id'].tolist()
len(authors)
# Out:
# 65

# %%
output_file = '/paper_jsons/paperJson.txt'
output_dir = base_dir + output_file
original_stdout = sys.stdout  
with open(output_dir, 'w') as f:
    sys.stdout = f 
    for i in range(len(authorId)):
        fetch_paper_json(author_id = authorId[i], year = 2023)
    sys.stdout = original_stdout

# %%
# checking if we have all jsons
! cd data/paper_jsons && ls | grep '\.json$' | wc -l
# Out:
#       50

# %%
# paper_id = csv.reader(open('data/paper/processed_output/paperId.csv', 'r'))
input_name = '/paper_logs/paperId.csv'
input_dir = base_dir + input_name
paper_id = csv.reader(open(input_dir, 'r'))
paper_ids = []
titles = []
authors = []
for row in paper_id:
    paper_ids.append(row[0])  # Access the first column for paper ID
    titles.append(row[1])  # Access the second column for title
    authors.append(row[2])

# %%
len(paper_ids[1:])
# Out:
# 337

# %%
# output = subprocess.getoutput(f'python semantic_scholar_simple.py -d {dir} {paper_ids[1]}')
# output

# %%
# Setup logging
failed_downloads = pd.DataFrame(columns=['author', 'paper_id', 'title'])

logging_output = 'data/paper_logs/download_logs_manual_updated.txt'
logging.basicConfig(filename=logging_output, level=logging.INFO, format='%(asctime)s - %(message)s')
dir = os.path.abspath('data/papers')  # Use absolute paths
os.makedirs(dir, exist_ok=True)  # Ensure directory exists

for i in range(1,len(paper_ids)):
    paper_id = paper_ids[i]
    title = titles[i]
    author = authors[i]
    file_path = os.path.join(dir, f"{paper_id}.pdf")
    logging.info('_______________________________________________________________________')
    logging.info(f'i: {i}, paper_id: {paper_id}, title: {title}, author:{author}')
    # print(f"title: {title}, author:{author}")
    if os.path.exists(file_path):
        logging.info(f"Downloaded already")
    else:
        output = subprocess.getoutput(f'python semantic_scholar_simple.py -d {dir} {paper_id}')
        logging.info(output)
        # print(output)
        if "Downloaded" in output and paper_id in output:  
            logging.info(f"Successfully downloaded")
        else:
            logging.error(f"Download failed")

# %%
# Setup logging
failed_downloads = pd.DataFrame(columns=['author', 'paper_id', 'title'])

logging_output = 'data/paper_logs/download_logs_manual.txt'
logging.basicConfig(filename=logging_output, level=logging.INFO, format='%(asctime)s - %(message)s')
dir = os.path.abspath('data/papers')  # Use absolute paths
os.makedirs(dir, exist_ok=True)  # Ensure directory exists

for i in range(1,len(paper_ids)):
    paper_id = paper_ids[i]
    title = titles[i]
    author = authors[i]
    file_path = os.path.join(dir, f"{paper_id}.pdf")
    print('_____________________________________________________________________')
    print(f"title: {title}, author:{author}")
    if os.path.exists(file_path):
        logging.info(f"Downloaded already '{paper_id}, title: {title}, author:{author}'")
    else:
        output = subprocess.getoutput(f'python semantic_scholar_simple.py -d {dir} {paper_id}')
        
        print(output)
        
        if "Downloaded" in output and paper_id in output:  
            logging.info(f"Successfully downloaded '{paper_id}, title: {title}, author:{author}'")
        else:
            logging.error(f"Download failed for {paper_id}, title: {title}, author:{author}")
# Out:
# _____________________________________________________________________
# title: Towards Open-Domain Twitter User Profile Inference, author:Alexander Hauptmann
# Downloaded '72cce47fd053bf916314d89a8174726c58c05e02' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/72cce47fd053bf916314d89a8174726c58c05e02.pdf'
# _____________________________________________________________________
# title: Zero-Shot and Few-Shot Stance Detection on Varied Topics via Conditional Generation, author:A. Hauptmann
# Downloaded '2107b867cb8f8afa30a9a940288d7c8b657f8aa5' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/2107b867cb8f8afa30a9a940288d7c8b657f8aa5.pdf'
# _____________________________________________________________________
# title: SPAE: Semantic Pyramid AutoEncoder for Multimodal Generation with Frozen LLMs, author:A. Hauptmann
# Downloaded '376f494126d1ea4f571ea0263c43ac2b6331800a' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/376f494126d1ea4f571ea0263c43ac2b6331800a.pdf'
# _____________________________________________________________________
# title: STMT: A Spatial-Temporal Mesh Transformer for MoCap-Based Action Recognition, author:A. Hauptmann
# Downloaded '405e3910e06c9efe7e660b8697bcb4bab4e92f48' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/405e3910e06c9efe7e660b8697bcb4bab4e92f48.pdf'
# _____________________________________________________________________
# title: DocumentNet: Bridging the Data Gap in Document Pre-training, author:A. Hauptmann
# Downloaded '8ccda6de0223bcd897d5dc0efc8f33222a899d0d' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/8ccda6de0223bcd897d5dc0efc8f33222a899d0d.pdf'
# _____________________________________________________________________
# title: Advancing Regular Language Reasoning in Linear Recurrent Neural Networks, author:Alexander I. Rudnicky
# Downloaded '06a8f2e3c4266196b008851f1ec7ef9f340809da' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/06a8f2e3c4266196b008851f1ec7ef9f340809da.pdf'
# _____________________________________________________________________
# title: Structured Dialogue Discourse Parsing, author:Alexander I. Rudnicky
# Downloaded '2670612b5e11297cd9b98f4d7ff796725f77fe35' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/2670612b5e11297cd9b98f4d7ff796725f77fe35.pdf'
# _____________________________________________________________________
# title: A Vector Quantized Approach for Text to Speech Synthesis on Real-World Spontaneous Speech, author:Alexander I. Rudnicky
# Downloaded '4b8d3ede673ddeab9dfb5184da6b748d7a526754' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/4b8d3ede673ddeab9dfb5184da6b748d7a526754.pdf'
# _____________________________________________________________________
# title: Overview of Robust and Multilingual Automatic Evaluation Metrics
#
# for Open-Domain Dialogue Systems at DSTC 11 Track 4, author:Alexander I. Rudnicky
# Downloaded '9799c17fd287bb9e8d231fe032c6dbf9c0c9d675' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/9799c17fd287bb9e8d231fe032c6dbf9c0c9d675.pdf'
# _____________________________________________________________________
# title: Learning to Ask Questions for Zero-shot Dialogue State Tracking, author:Alexander I. Rudnicky
# Failed to download 'f743324682d5d50db9b114fa60b908f09c10c9a0': HTTPError: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/pdf/10.1145/3539618.3592010
# _____________________________________________________________________
# title: Latent Positional Information is in the Self-Attention Variance of Transformer Language Models Without Positional Embeddings, author:A. Rudnicky
# Downloaded '161bf3f0705ef8e088f53b383363338daac9af44' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/161bf3f0705ef8e088f53b383363338daac9af44.pdf'
# _____________________________________________________________________
# title: Transformer Working Memory Enables Regular Language Reasoning and Natural Language Length Extrapolation, author:A. Rudnicky
# Downloaded '465ec2212d865e875e64638b3dd1ecaac21c5ddd' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/465ec2212d865e875e64638b3dd1ecaac21c5ddd.pdf'
# _____________________________________________________________________
# title: AdapITN: A Fast, Reliable, and Dynamic Adaptive Inverse Text Normalization, author:A. Waibel
# 'aab2ed83bc3739a20e90ae1d97dcf45f3bc8e508' is not open access
# _____________________________________________________________________
# title: Train Global, Tailor Local: Minimalist Multilingual Translation into Endangered Languages, author:A. Waibel
# Downloaded 'f3e237e794bc4cd8df7f3e31d0caa2f7ee8cd06b' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/f3e237e794bc4cd8df7f3e31d0caa2f7ee8cd06b.pdf'
# _____________________________________________________________________
# title: Towards Efficient Simultaneous Speech Translation: CUNI-KIT System for Simultaneous Track at IWSLT 2023, author:A. Waibel
# Downloaded 'f547c7ec86cbc0989e87f0e23f7e0b2cfc5259c3' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/f547c7ec86cbc0989e87f0e23f7e0b2cfc5259c3.pdf'
# _____________________________________________________________________
# title: SYNTACC : Synthesizing Multi-Accent Speech By Weight Factorization, author:A. Waibel
# '100eb82862a66e264686d015934c97c54bdadb4f' is not open access
# _____________________________________________________________________
# title: KIT’s Multilingual Speech Translation System for IWSLT 2023, author:A. Waibel
# Downloaded '610d9958390ab83515d0d81e19f8e5264faf8e9b' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/610d9958390ab83515d0d81e19f8e5264faf8e9b.pdf'
# _____________________________________________________________________
# title: Convoifilter: A case study of doing cocktail party speech recognition, author:A. Waibel
# Downloaded '7e13fcb7b7bae202fb9087e87abaa71a4b19a3e3' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/7e13fcb7b7bae202fb9087e87abaa71a4b19a3e3.pdf'
# _____________________________________________________________________
# title: Incremental Blockwise Beam Search for Simultaneous Speech Translation with Controllable Quality-Latency Tradeoff, author:A. Waibel
# Downloaded 'd24d60719e90e69749a75c160cb760d1d9fca44a' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/d24d60719e90e69749a75c160cb760d1d9fca44a.pdf'
# _____________________________________________________________________
# title: End-to-End Evaluation for Low-Latency Simultaneous Speech Translation, author:A. Waibel
# Downloaded 'f524f119afc13cc07ca15998c10b9509e9e9b0b5' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/f524f119afc13cc07ca15998c10b9509e9e9b0b5.pdf'
# _____________________________________________________________________
# title: FINDINGS OF THE IWSLT 2023 EVALUATION CAMPAIGN, author:A. Waibel
# Downloaded 'f7e995c3cae465963ecaa8c9b4ce8b9b4323a71b' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/f7e995c3cae465963ecaa8c9b4ce8b9b4323a71b.pdf'
# _____________________________________________________________________
# title: The Inside Story: Towards Better Understanding of Machine Translation Neural Evaluation Metrics, author:A. Lavie
# Downloaded '10127fa44054eb985ede206113b96aac3a96fd80' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/10127fa44054eb985ede206113b96aac3a96fd80.pdf'
# _____________________________________________________________________
# title: Towards Multilingual Automatic Dialogue Evaluation, author:A. Lavie
# Downloaded '5579d38636b898c6a67ad67a16a80dd83be0f8d4' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/5579d38636b898c6a67ad67a16a80dd83be0f8d4.pdf'
# _____________________________________________________________________
# title: Results of WMT23 Metrics Shared Task: Metrics Might Be Guilty but References Are Not Innocent, author:A. Lavie
# Downloaded '5c920b2326282d93ad2ac3d1cb8f746bd7ab6f50' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/5c920b2326282d93ad2ac3d1cb8f746bd7ab6f50.pdf'
# _____________________________________________________________________
# title: Appropriateness is all you need!, author:A. Lavie
# Downloaded '9364720b2ab9ac67bc08e2b0b49aadded3d4e2e5' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/9364720b2ab9ac67bc08e2b0b49aadded3d4e2e5.pdf'
# _____________________________________________________________________
# title: Towards Multilingual Automatic Open-Domain Dialogue Evaluation, author:A. Lavie
# Downloaded '9e8f125ef479af7e95ee5b8949b24e750c7df367' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/9e8f125ef479af7e95ee5b8949b24e750c7df367.pdf'
# _____________________________________________________________________
# title: Simple LLM Prompting is State-of-the-Art for Robust and Multilingual Dialogue Evaluation, author:A. Lavie
# Downloaded 'bcefc74b20649fd41ea05d87a3fa512d2559fc8d' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/bcefc74b20649fd41ea05d87a3fa512d2559fc8d.pdf'
# _____________________________________________________________________
# title: FREDOM: Fairness Domain Adaptation Approach to Semantic Scene Understanding, author:B. Raj
# Downloaded '078f86c6a691806cc71bbef1e734f75690db0ffc' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/078f86c6a691806cc71bbef1e734f75690db0ffc.pdf'
# _____________________________________________________________________
# title: UTOPIA: Unconstrained Tracking Objects without Preliminary Examination via Cross-Domain Adaptation, author:B. Raj
# Downloaded '0a8d38686b18f28aae1222529e6b9e8a60cab1c2' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/0a8d38686b18f28aae1222529e6b9e8a60cab1c2.pdf'
# _____________________________________________________________________
# title: SoftMatch: Addressing the Quantity-Quality Trade-off in Semi-supervised Learning, author:B. Raj
# Downloaded '100da279ee981960884a12dfc5a0697c24ed315a' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/100da279ee981960884a12dfc5a0697c24ed315a.pdf'
# _____________________________________________________________________
# title: Fixed Inter-Neuron Covariability Induces Adversarial Robustness, author:B. Raj
# Downloaded '11c50900f50036fb3247be7c83849a8774a4ba60' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/11c50900f50036fb3247be7c83849a8774a4ba60.pdf'
# _____________________________________________________________________
# title: Understanding political polarization using language models: A dataset and method, author:B. Raj
# Failed to download '22c9eb4868c5cabb26d132e0a160b9a093579f08': HTTPError: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/aaai.12104
# _____________________________________________________________________
# title: Prolonged school closure during the pandemic time in successive waves of COVID-19- vulnerability of children to sexual abuses – A case study in Tamil Nadu, India, author:B. Raj
# Failed to download '35a8802facb4441787017ac5c630a8fa0f2413bd': HTTPError: 403 Client Error: Forbidden for url: https://www.cell.com/article/S2405844023050739/pdf
# _____________________________________________________________________
# title: BASS: Block-wise Adaptation for Speech Summarization, author:B. Raj
# Downloaded '3bd320ddb25886417ae90011b00f13f5d558097b' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/3bd320ddb25886417ae90011b00f13f5d558097b.pdf'
# _____________________________________________________________________
# title: Understanding Political Polarisation using Language Models: A dataset and method, author:B. Raj
# Downloaded '4e6a004e4f9a3b489004a2efb5b25b0bcd0f48b5' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/4e6a004e4f9a3b489004a2efb5b25b0bcd0f48b5.pdf'
# _____________________________________________________________________
# title: An Approach to Ontological Learning from Weak Labels, author:B. Raj
# '593a603354c09d151440ae044de1d80324a2ab01' is not open access
# _____________________________________________________________________
# title: Rethinking Voice-Face Correlation: A Geometry View, author:B. Raj
# Downloaded '5a3307b2e64bbcaff1202e261b8a83f7d03418a8' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/5a3307b2e64bbcaff1202e261b8a83f7d03418a8.pdf'
# _____________________________________________________________________
# title: Paaploss: A Phonetic-Aligned Acoustic Parameter Loss for Speech Enhancement, author:B. Raj
# Downloaded '611f9ee6eef0936462cd78f371798d0699951c59' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/611f9ee6eef0936462cd78f371798d0699951c59.pdf'
# _____________________________________________________________________
# title: Improving Perceptual Quality, Intelligibility, and Acoustics on VoIP Platforms, author:B. Raj
# Downloaded '7333be530df311b3148e9857ce9f481975cf0a9b' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/7333be530df311b3148e9857ce9f481975cf0a9b.pdf'
# _____________________________________________________________________
# title: Approach to Learning Generalized Audio Representation Through Batch Embedding Covariance Regularization and Constant-Q Transforms, author:B. Raj
# Downloaded '740488982dee323d559f2dae70b1f4b3aa5f7171' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/740488982dee323d559f2dae70b1f4b3aa5f7171.pdf'
# _____________________________________________________________________
# title: Training on Foveated Images Improves Robustness to Adversarial Attacks, author:B. Raj
# Downloaded '74664618ad3b44eb191ba96fdff5b93f27a29ced' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/74664618ad3b44eb191ba96fdff5b93f27a29ced.pdf'
# _____________________________________________________________________
# title: Imprecise Label Learning: A Unified Framework for Learning with Various Imprecise Label Configurations, author:B. Raj
# Downloaded '8665c864d71df1e918d2010778fc06712f4e5550' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/8665c864d71df1e918d2010778fc06712f4e5550.pdf'
# _____________________________________________________________________
# title: The Hidden Dance of Phonemes and Visage: Unveiling the Enigmatic Link between Phonemes and Facial Features, author:B. Raj
# Downloaded 'a6e3a10a6286967413e3406374bbeea533640030' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/a6e3a10a6286967413e3406374bbeea533640030.pdf'
# _____________________________________________________________________
# title: Fairness Continual Learning Approach to Semantic Scene Understanding in Open-World Environments, author:B. Raj
# Downloaded 'ac856b6b7b3f32fb34320b7170526d3ab15ba5f3' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/ac856b6b7b3f32fb34320b7170526d3ab15ba5f3.pdf'
# _____________________________________________________________________
# title: PaintSeg: Training-free Segmentation via Painting, author:B. Raj
# Downloaded 'dc157eba8bdb4cfe6ee65566d8295939ac5b4b37' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/dc157eba8bdb4cfe6ee65566d8295939ac5b4b37.pdf'
# _____________________________________________________________________
# title: TAPLoss: A Temporal Acoustic Parameter Loss for Speech Enhancement, author:B. Raj
# Downloaded 'e146e5221c124d93f69516c5ae7e1b7b1822848e' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/e146e5221c124d93f69516c5ae7e1b7b1822848e.pdf'
# _____________________________________________________________________
# title: Synergy between human and machine approaches to sound/scene recognition and processing: An overview of ICASSP special session, author:B. Raj
# Downloaded 'feecd2cfb7871a818ba514e8b4b3f9da482f17bc' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/feecd2cfb7871a818ba514e8b4b3f9da482f17bc.pdf'
# _____________________________________________________________________
# title: Assessment and Therapy Goal Planning Using Free Computerized Language Analysis Software., author:B. MacWhinney
# '02a626bd8538ecb675bd2bcd8f5985274e965d00' is not open access
# _____________________________________________________________________
# title: Automation of Language Sample Analysis, author:B. MacWhinney
# '0773228ecc4c1f2d729c0ae5764c77c1c9bb9573' is not open access
# _____________________________________________________________________
# title: The role of novelty stimuli in second language acquisition: evidence from the optimized training by the Pinyin Tutor at TalkBank, author:B. MacWhinney
# Downloaded '283dbaa4da4beafa5e5719095bcc88e63d17815e' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/283dbaa4da4beafa5e5719095bcc88e63d17815e.pdf'
# _____________________________________________________________________
# title: Using diagnostic feedback to enhance the development of phonetic knowledge of an L2: a CALL design based on the unified competition model and the implementation with the Pinyin Tutor, author:B. MacWhinney
# Downloaded '3859f18277f0c5876a53411b07f80d65254c52e5' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/3859f18277f0c5876a53411b07f80d65254c52e5.pdf'
# _____________________________________________________________________
# title: A New Benchmark of Aphasia Speech Recognition and Detection Based on E-Branchformer and Multi-task Learning, author:B. MacWhinney
# Downloaded '4d35540aaf993c8fa7e1fa5fc6a990f1eb830263' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/4d35540aaf993c8fa7e1fa5fc6a990f1eb830263.pdf'
# _____________________________________________________________________
# title: Collaborative Commentary for Understanding Communication Disorders., author:B. MacWhinney
# '52b48ab5d7d87642395818bea1ff804ff6dd0bd3' is not open access
# _____________________________________________________________________
# title: Establishing the DementiaBank Delaware Corpus: An Online Multimedia Database for the Study of Language and Cognition in Dementia, author:B. MacWhinney
# Failed to download 'cf152ac1b3c9daea5b48f858acc13193a83df185': HTTPError: 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/alz.073058
# _____________________________________________________________________
# title: Evaluating Picture Description Speech for Dementia Detection using Image-text Alignment, author:B. MacWhinney
# Downloaded 'd898963243ad4b177b799f197a7732395e165cf6' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/d898963243ad4b177b799f197a7732395e165cf6.pdf'
# _____________________________________________________________________
# title: Multilingual Alzheimer’s Dementia Recognition through Spontaneous Speech: A Signal Processing Grand Challenge, author:B. MacWhinney
# Downloaded 'f1ebdd8c99aa33284e3604c28b72efa9dc46047c' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/f1ebdd8c99aa33284e3604c28b72efa9dc46047c.pdf'
# _____________________________________________________________________
# title: DementiaBank: Theoretical Rationale, Protocol, and Illustrative Analyses, author:B. MacWhinney
# 'f7254ae607056ba5522c10dbcf21b394967b6d42' is not open access
# _____________________________________________________________________
# title: High school students’ data modeling practices and processes: from modeling unstructured data to evaluating automated decisions, author:C. Rosé
# Failed to download '06dc7b3d8cbc40fb4e39b42de1bc664deaacca74': HTTPError: 403 Client Error: Forbidden for url: https://www.tandfonline.com/doi/pdf/10.1080/17439884.2023.2189735?needAccess=true&role=button
# _____________________________________________________________________
# title: Linguistic representations for fewer-shot relation extraction across domains, author:C. Rosé
# Downloaded '0c0d8ea1c1745e7b56bc3b1513a715ae3df30c44' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/0c0d8ea1c1745e7b56bc3b1513a715ae3df30c44.pdf'
# _____________________________________________________________________
# title: Using counterfactual contrast to improve compositional generalization for multi-step quantitative reasoning, author:C. Rosé
# Downloaded '117e1323677cb5d78ece0fd07b5cfa81618f4866' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/117e1323677cb5d78ece0fd07b5cfa81618f4866.pdf'
# _____________________________________________________________________
# title: Towards Extracting and Understanding the Implicit Rubrics of Transformer Based Automatic Essay Scoring Models, author:C. Rosé
# Downloaded '15d85036b15388bcb0199c83c01ba833e6095a31' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/15d85036b15388bcb0199c83c01ba833e6095a31.pdf'
# _____________________________________________________________________
# title: Exploring Artificial Intelligence in English Language Arts with StoryQ, author:C. Rosé
# Downloaded '27ca2d927421035e10b48c96a96db32224f1f8e6' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/27ca2d927421035e10b48c96a96db32224f1f8e6.pdf'
# _____________________________________________________________________
# title: Text Matching Improves Sequential Recommendation by Reducing Popularity Biases, author:Chenyan Xiong
# Downloaded '159100c8323fc558e4073a3a006f3f243aca3a60' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/159100c8323fc558e4073a3a006f3f243aca3a60.pdf'
# _____________________________________________________________________
# title: Fusion-in-T5: Unifying Document Ranking Signals for Improved Information Retrieval, author:Chenyan Xiong
# Downloaded '275da3802142fc42f6fab2ce2104223b2e0ef40d' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/275da3802142fc42f6fab2ce2104223b2e0ef40d.pdf'
# _____________________________________________________________________
# title: OpenMatch-v2: An All-in-one Multi-Modality PLM-based Information Retrieval Toolkit, author:Chenyan Xiong
# Failed to download 'cdfd0926ad26c3c95a02db2ae891b7d4a457429c': HTTPError: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/pdf/10.1145/3539618.3591813
# _____________________________________________________________________
# title: Improving Multitask Retrieval by Promoting Task Specialization, author:Chenyan Xiong
# Downloaded '105759bdb5e3bddc1d3244df2eff2d5c997a1d84' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/105759bdb5e3bddc1d3244df2eff2d5c997a1d84.pdf'
# _____________________________________________________________________
# title: Unsupervised Dense Retrieval Training with Web Anchors, author:Chenyan Xiong
# Failed to download '1fe3a802efdc4f1a3e5c8187547f38a3ec65750b': HTTPError: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/pdf/10.1145/3539618.3592080
# _____________________________________________________________________
# title: Augmentation-Adapted Retriever Improves Generalization of Language Models as Generic Plug-In, author:Chenyan Xiong
# Downloaded '24811cadf16519910f643b6084107164e6ca4219' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/24811cadf16519910f643b6084107164e6ca4219.pdf'
# _____________________________________________________________________
# title: Model-Generated Pretraining Signals Improves Zero-Shot Generalization of Text-to-Text Transformers, author:Chenyan Xiong
# Downloaded '38aaf8a29df6deeff0bf64cc835d242a25b10337' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/38aaf8a29df6deeff0bf64cc835d242a25b10337.pdf'
# _____________________________________________________________________
# title: Structure-Aware Language Model Pretraining Improves Dense Retrieval on Structured Data, author:Chenyan Xiong
# Downloaded 'a57b90cfc2eab46b773e65240d4ff910f05f989e' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/a57b90cfc2eab46b773e65240d4ff910f05f989e.pdf'
# _____________________________________________________________________
# title: Toolink: Linking Toolkit Creation and Using through Chain-of-Solving on Open-Source Model, author:Chenyan Xiong
# Downloaded 'b9e8b62bcc019f47a0a015568f70039b3b7c1196' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/b9e8b62bcc019f47a0a015568f70039b3b7c1196.pdf'
# _____________________________________________________________________
# title: Augmenting Zero-Shot Dense Retrievers with Plug-in Mixture-of-Memories, author:Chenyan Xiong
# Downloaded 'e0401ca2d4fd6d0ed55130a4a24b33ed90111479' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/e0401ca2d4fd6d0ed55130a4a24b33ed90111479.pdf'
# _____________________________________________________________________
# title: Pragmatic Inference with a CLIP Listener for Contrastive Captioning, author:Daniel Fried
# Downloaded '19f59c14b3d79e3203c696128a135d33eb35e468' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/19f59c14b3d79e3203c696128a135d33eb35e468.pdf'
# _____________________________________________________________________
# title: SantaCoder: don't reach for the stars!, author:Daniel Fried
# Downloaded '1bf21dabbdfc81fd4f9e92b1201ecce744cabb6a' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/1bf21dabbdfc81fd4f9e92b1201ecce744cabb6a.pdf'
# _____________________________________________________________________
# title: Grounding Language Models to Images for Multimodal Generation, author:Daniel Fried
# Downloaded '2b2d9ee18507aa89a7f1ecba0bf68844c7d9aa75' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/2b2d9ee18507aa89a7f1ecba0bf68844c7d9aa75.pdf'
# _____________________________________________________________________
# title: StarCoder: may the source be with you!, author:Daniel Fried
# Downloaded '3e4085e5869f1b7959707a1e1d7d273b6057eb4e' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/3e4085e5869f1b7959707a1e1d7d273b6057eb4e.pdf'
# _____________________________________________________________________
# title: Generating Images with Multimodal Language Models, author:Daniel Fried
# Downloaded '6fb5c0eff3696ef252aca9638e10176ecce7cecb' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/6fb5c0eff3696ef252aca9638e10176ecce7cecb.pdf'
# _____________________________________________________________________
# title: WebArena: A Realistic Web Environment for Building Autonomous Agents, author:Daniel Fried
# Downloaded 'e41482f4ee984f17382f6cdd900df094d928be06' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/e41482f4ee984f17382f6cdd900df094d928be06.pdf'
# _____________________________________________________________________
# title: Reverse-Engineering Decoding Strategies Given Blackbox Access to a Language Generation System, author:Daphne Ippolito
# Downloaded '03fb535de5cfcf435705a079334ac60f501226ab' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/03fb535de5cfcf435705a079334ac60f501226ab.pdf'
# _____________________________________________________________________
# title: A Pretrainer's Guide to Training Data: Measuring the Effects of Data Age, Domain Coverage, Quality, & Toxicity, author:Daphne Ippolito
# Downloaded '1567bcac0ab09269c9d0ff33c9a406132417fab9' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/1567bcac0ab09269c9d0ff33c9a406132417fab9.pdf'
# _____________________________________________________________________
# title: Extracting Training Data from Diffusion Models, author:Daphne Ippolito
# Downloaded '2e965b5d97c2d6fb4af284307735be39283792ba' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/2e965b5d97c2d6fb4af284307735be39283792ba.pdf'
# _____________________________________________________________________
# title: Are aligned neural networks adversarially aligned?, author:Daphne Ippolito
# Downloaded '8724579d3f126e753a0451d98ff57b165f722e72' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/8724579d3f126e753a0451d98ff57b165f722e72.pdf'
# _____________________________________________________________________
# title: ChatGPT MT: Competitive for High- (but Not Low-) Resource Languages, author:David R. Mortensen
# Downloaded '11a571eaab42a6ffb1d938635a093315e392756d' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/11a571eaab42a6ffb1d938635a093315e392756d.pdf'
# _____________________________________________________________________
# title: Do All Languages Cost the Same? Tokenization in the Era of Commercial Language Models, author:David R. Mortensen
# Downloaded '17fbffb05fa14e21d1c506fd5f0f568b955fe983' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/17fbffb05fa14e21d1c506fd5f0f568b955fe983.pdf'
# _____________________________________________________________________
# title: SigMoreFun Submission to the SIGMORPHON Shared Task on Interlinear Glossing, author:David R. Mortensen
# Downloaded '659be1ff350634f50cc066d258ee6a45e697e552' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/659be1ff350634f50cc066d258ee6a45e697e552.pdf'
# _____________________________________________________________________
# title: Construction Grammar Provides Unique Insight into Neural Language Models, author:David R. Mortensen
# Downloaded '7a08051aac75a809737096e39820bf836908d4e1' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/7a08051aac75a809737096e39820bf836908d4e1.pdf'
# _____________________________________________________________________
# title: Generalized Glossing Guidelines: An Explicit, Human- and Machine-Readable, Item-and-Process Convention for Morphological Annotation, author:David R. Mortensen
# Downloaded 'bf42c0462d1415cdde877c90d58da11545407b8a' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/bf42c0462d1415cdde877c90d58da11545407b8a.pdf'
# _____________________________________________________________________
# title: Transformed Protoform Reconstruction, author:David R. Mortensen
# Downloaded 'c5c6d006e399386c99068daba138021a62d6cc17' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/c5c6d006e399386c99068daba138021a62d6cc17.pdf'
# _____________________________________________________________________
# title: PWESuite: Phonetic Word Embeddings and Tasks They Facilitate, author:David R. Mortensen
# Downloaded 'db14d05b18ec852f8afcd6d2d10bbd9eeaef8325' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/db14d05b18ec852f8afcd6d2d10bbd9eeaef8325.pdf'
# _____________________________________________________________________
# title: To Build Our Future, We Must Know Our Past: Contextualizing Paradigm Shifts in Natural Language Processing, author:Emma Strubell
# Downloaded '1433b8d43d446fcc7f3e1370b22f744a4dd7c8e4' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/1433b8d43d446fcc7f3e1370b22f744a4dd7c8e4.pdf'
# _____________________________________________________________________
# title: Understanding the Effect of Model Compression on Social Bias in Large Language Models, author:Emma Strubell
# Downloaded '45e50baac4d341f0cf1a40af096bfa9c3f555235' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/45e50baac4d341f0cf1a40af096bfa9c3f555235.pdf'
# _____________________________________________________________________
# title: Surveying (Dis)Parities and Concerns of Compute Hungry NLP Research, author:Emma Strubell
# Downloaded '667ba2e8f1933b6c32e9672012526904b4c5dc31' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/667ba2e8f1933b6c32e9672012526904b4c5dc31.pdf'
# _____________________________________________________________________
# title: On the Interactions of Structural Constraints and Data Resources for Structured Prediction, author:Emma Strubell
# Downloaded '71debf888acd57bb1baa4c146f31e58c66ea51af' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/71debf888acd57bb1baa4c146f31e58c66ea51af.pdf'
# _____________________________________________________________________
# title: Efficiency Pentathlon: A Standardized Arena for Efficiency Evaluation, author:Emma Strubell
# Downloaded '84d20ad9f42d80dfd5130a6362d5422be8a6bdc3' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/84d20ad9f42d80dfd5130a6362d5422be8a6bdc3.pdf'
# _____________________________________________________________________
# title: Queer People are People First: Deconstructing Sexual Identity Stereotypes in Large Language Models, author:Emma Strubell
# Downloaded '88549b4f48b9709acdfb8b9e41656b6d133c5390' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/88549b4f48b9709acdfb8b9e41656b6d133c5390.pdf'
# _____________________________________________________________________
# title: Making Scalable Meta Learning Practical, author:Emma Strubell
# Downloaded 'a815c3209e7baff4466dbf6e129129511f842b7e' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/a815c3209e7baff4466dbf6e129129511f842b7e.pdf'
# _____________________________________________________________________
# title: Regularizing Self-training for Unsupervised Domain Adaptation via Structural Constraints, author:Emma Strubell
# Downloaded 'b13da1161d65a8de7a96051b5bc68d5eaa8eb37b' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/b13da1161d65a8de7a96051b5bc68d5eaa8eb37b.pdf'
# _____________________________________________________________________
# title: The Framework Tax: Disparities Between Inference Efficiency in Research and Deployment, author:Emma Strubell
# Downloaded 'b777aa86b5a1d49ce8eababc5c2ee56d3562801e' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/b777aa86b5a1d49ce8eababc5c2ee56d3562801e.pdf'
# _____________________________________________________________________
# title: Data-efficient Active Learning for Structured Prediction with Partial Annotation and Self-Training, author:Emma Strubell
# Downloaded 'ba31ccac5fe5ea151727e8427e78bb300c35f899' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/ba31ccac5fe5ea151727e8427e78bb300c35f899.pdf'
# _____________________________________________________________________
# title: GameQA: Gamified Mobile App Platform for Building Multiple-Domain Question-Answering Datasets, author:Eric Nyberg
# Downloaded '0f008e07d601e8f21d1df5db3d36e85484840083' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/0f008e07d601e8f21d1df5db3d36e85484840083.pdf'
# _____________________________________________________________________
# title: InPars-Light: Cost-Effective Unsupervised Training of Efficient Rankers, author:Eric Nyberg
# Downloaded '3a30217c4115777fb30c182c97cc77d34d065556' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/3a30217c4115777fb30c182c97cc77d34d065556.pdf'
# _____________________________________________________________________
# title: Language-Agnostic Transformers and Assessing ChatGPT-Based Query Rewriting for Multilingual Document-Grounded QA, author:Eric Nyberg
# Downloaded '444737639aeea4e1e616509e368afb0bae8f89d6' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/444737639aeea4e1e616509e368afb0bae8f89d6.pdf'
# _____________________________________________________________________
# title: Chain-of-Skills: A Configurable Model for Open-Domain Question Answering, author:Eric Nyberg
# Downloaded '61354e45bca908ad08f24e44bd507b4e1c958e6f' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/61354e45bca908ad08f24e44bd507b4e1c958e6f.pdf'
# _____________________________________________________________________
# title: Identification of Nonlinear Latent Hierarchical Models, author:E. Xing
# Downloaded '075b751201f549daeba9840f78768f4ceb507e17' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/075b751201f549daeba9840f78768f4ceb507e17.pdf'
# _____________________________________________________________________
# title: StyleRF: Zero-Shot 3D Style Transfer of Neural Radiance Fields, author:E. Xing
# Downloaded '8cc1cd002bfc36a8cba8bcbe63d32eacc656097f' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/8cc1cd002bfc36a8cba8bcbe63d32eacc656097f.pdf'
# _____________________________________________________________________
# title: Judging LLM-as-a-judge with MT-Bench and Chatbot Arena, author:E. Xing
# Downloaded 'a0a79dad89857a96f8f71b14238e5237cbfc4787' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/a0a79dad89857a96f8f71b14238e5237cbfc4787.pdf'
# _____________________________________________________________________
# title: Understanding Masked Autoencoders via Hierarchical Latent Variable Models, author:E. Xing
# Downloaded 'dcb4f2b9b0e6da0d629878d1ad0469aee3df2020' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/dcb4f2b9b0e6da0d629878d1ad0469aee3df2020.pdf'
# _____________________________________________________________________
# title: Best-Case Retrieval Evaluation: Improving the Sensitivity of Reciprocal Rank with Lexicographic Precision, author:Fernando Diaz
# Downloaded '55704caaf3d31e1795a1ca0c3bed9e77ae3a3c95' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/55704caaf3d31e1795a1ca0c3bed9e77ae3a3c95.pdf'
# _____________________________________________________________________
# title: Fairness Through Domain Awareness: Mitigating Popularity Bias For Music Discovery, author:Fernando Diaz
# Downloaded '567f6bc975deb3d728feec9bfcf7d4036ceabb12' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/567f6bc975deb3d728feec9bfcf7d4036ceabb12.pdf'
# _____________________________________________________________________
# title: Overview of the TREC 2021 Fair Ranking Track, author:Fernando Diaz
# Downloaded '5e1ba2d4416333dd6f6a31a4ff4221b40dfb74b1' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/5e1ba2d4416333dd6f6a31a4ff4221b40dfb74b1.pdf'
# _____________________________________________________________________
# title: Cross-Modal Fine-Tuning: Align then Refine, author:Graham Neubig
# Downloaded '03c7f61b0c6bc4c480ed6da4e9d7dda104ddfec3' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/03c7f61b0c6bc4c480ed6da4e9d7dda104ddfec3.pdf'
# _____________________________________________________________________
# title: GlobalBench: A Benchmark for Global Progress in Natural Language Processing, author:Graham Neubig
# Downloaded '17605c43ca3eb982c99642052ddc21a93d116594' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/17605c43ca3eb982c99642052ddc21a93d116594.pdf'
# _____________________________________________________________________
# title: Learning Performance-Improving Code Edits, author:Graham Neubig
# Downloaded '1786a2f9140ed7211b21302977de64e948b92308' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/1786a2f9140ed7211b21302977de64e948b92308.pdf'
# _____________________________________________________________________
# title: CodeBERTScore: Evaluating Code Generation with Pretrained Models of Code, author:Graham Neubig
# Downloaded '31366ff634fc905affd78dbd8ddc9a872c006a87' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/31366ff634fc905affd78dbd8ddc9a872c006a87.pdf'
# _____________________________________________________________________
# title: Neural Machine Translation for the Indigenous Languages of the Americas: An Introduction, author:Graham Neubig
# Downloaded '405f1a5602867c66e015491c26d2be5504eed458' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/405f1a5602867c66e015491c26d2be5504eed458.pdf'
# _____________________________________________________________________
# title: User-Centric Evaluation of OCR Systems for Kwak’wala, author:Graham Neubig
# Downloaded '43c0f77f116f986b53eb04f5c9b33f10132ded55' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/43c0f77f116f986b53eb04f5c9b33f10132ded55.pdf'
# _____________________________________________________________________
# title: Multi-Dimensional Evaluation of Text Summarization with In-Context Learning, author:Graham Neubig
# Downloaded '4d74a5048b884e8bb3842240abf98915c619c8f8' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/4d74a5048b884e8bb3842240abf98915c619c8f8.pdf'
# _____________________________________________________________________
# title: A Gold Standard Dataset for the Reviewer Assignment Problem, author:Graham Neubig
# Downloaded '5ea8eedcb31859c5730dd1da3804e1be529ffabb' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/5ea8eedcb31859c5730dd1da3804e1be529ffabb.pdf'
# _____________________________________________________________________
# title: Bridging the Gap: A Survey on Integrating (Human) Feedback for Natural Language Generation, author:Graham Neubig
# Downloaded '74b05bba46db21e589a2cc0f916f81069b0368ef' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/74b05bba46db21e589a2cc0f916f81069b0368ef.pdf'
# _____________________________________________________________________
# title: FacTool: Factuality Detection in Generative AI - A Tool Augmented Framework for Multi-Task and Multi-Domain Scenarios, author:Graham Neubig
# Downloaded '7a5b44ea10a51708e18786595c8d70b18950da11' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/7a5b44ea10a51708e18786595c8d70b18950da11.pdf'
# _____________________________________________________________________
# title: Active Retrieval Augmented Generation, author:Graham Neubig
# Downloaded '88884b8806262a4095036041e3567d450dba39f7' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/88884b8806262a4095036041e3567d450dba39f7.pdf'
# _____________________________________________________________________
# title: Large Language Models Enable Few-Shot Clustering, author:Graham Neubig
# Downloaded '8e8a1489bf4d782d2435cdeb93f7d1f165747c63' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/8e8a1489bf4d782d2435cdeb93f7d1f165747c63.pdf'
# _____________________________________________________________________
# title: Solving NLP Problems through Human-System Collaboration: A Discussion-based Approach, author:Graham Neubig
# Downloaded '9bce3661f01825ad56dc9d2b3d254fd9e3792360' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/9bce3661f01825ad56dc9d2b3d254fd9e3792360.pdf'
# _____________________________________________________________________
# title: Crossing the Threshold: Idiomatic Machine Translation through Retrieval Augmentation and Loss Weighting, author:Graham Neubig
# Downloaded 'b4987da792dd45a84232cfb06d71b1c2ec488f38' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/b4987da792dd45a84232cfb06d71b1c2ec488f38.pdf'
# _____________________________________________________________________
# title: Why do Nearest Neighbor Language Models Work?, author:Graham Neubig
# Downloaded 'c432aff446d55e72a28394a1508e760cc9a25c08' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/c432aff446d55e72a28394a1508e760cc9a25c08.pdf'
# _____________________________________________________________________
# title: Syntax and Semantics Meet in the “Middle”: Probing the Syntax-Semantics Interface of LMs Through Agentivity, author:Graham Neubig
# Downloaded 'c5207241406586f4263b235667e004b71ea68953' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/c5207241406586f4263b235667e004b71ea68953.pdf'
# _____________________________________________________________________
# title: DataFinder: Scientific Dataset Recommendation from Natural Language Descriptions, author:Graham Neubig
# Downloaded 'cc1705fe421c70d85254b557634bd4669fdd49b0' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/cc1705fe421c70d85254b557634bd4669fdd49b0.pdf'
# _____________________________________________________________________
# title: Multi-lingual and Multi-cultural Figurative Language Understanding, author:Graham Neubig
# Downloaded 'd5dd7230cccace7e77095d3b5fd8394850f59170' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/d5dd7230cccace7e77095d3b5fd8394850f59170.pdf'
# _____________________________________________________________________
# title: It’s MBR All the Way Down: Modern Generation Techniques Through the Lens of Minimum Bayes Risk, author:Graham Neubig
# Downloaded 'd6ae4c0679bdceb029f652efd2a854ac5ade772f' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/d6ae4c0679bdceb029f652efd2a854ac5ade772f.pdf'
# _____________________________________________________________________
# title: Unlimiformer: Long-Range Transformers with Unlimited Length Input, author:Graham Neubig
# Downloaded 'dbc368bc8b49347dd27679894524fa62f88492c9' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/dbc368bc8b49347dd27679894524fa62f88492c9.pdf'
# _____________________________________________________________________
# title: Prompt2Model: Generating Deployable Models from Natural Language Instructions, author:Graham Neubig
# Downloaded 'e69684fb06a7b1fe621d7ef0c97fc2ca0e122c43' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/e69684fb06a7b1fe621d7ef0c97fc2ca0e122c43.pdf'
# _____________________________________________________________________
# title: Computational Language Acquisition with Theory of Mind, author:Graham Neubig
# Downloaded 'e7b3b692b0816821aafc0d354749bc3802cbf6ac' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/e7b3b692b0816821aafc0d354749bc3802cbf6ac.pdf'
# _____________________________________________________________________
# title: Improving Factuality of Abstractive Summarization via Contrastive Reward Learning, author:Graham Neubig
# Downloaded 'f640e89fcede075b4bde3b2fa0dc78f591589ba3' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/f640e89fcede075b4bde3b2fa0dc78f591589ba3.pdf'
# _____________________________________________________________________
# title: The Devil Is in the Errors: Leveraging Large Language Models for Fine-grained Machine Translation Evaluation, author:Graham Neubig
# Downloaded 'fd80f7f3673fc6ca02f192d5d73426f11a4be659' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/fd80f7f3673fc6ca02f192d5d73426f11a4be659.pdf'
# _____________________________________________________________________
# title: Conversational Search with Random Walks over Entity Graphs, author:Jamie Callan
# Failed to download '197d5fbc3764ff18186275545d0764d5b1c7659b': HTTPError: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/pdf/10.1145/3578337.3605125
# _____________________________________________________________________
# title: KALE: Using a K-Sparse Projector for Lexical Expansion, author:Jamie Callan
# Failed to download '1e0a4ff0c5d2d850ff5907e310ffcedc9cad9718': HTTPError: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/pdf/10.1145/3578337.3605131
# _____________________________________________________________________
# title: CSurF: Sparse Lexical Retrieval through Contextualized Surface Forms, author:Jamie Callan
# Failed to download '6b7eefa15c0a461afeab4fa13cf862c5340fdc2a': HTTPError: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/pdf/10.1145/3578337.3605126
# _____________________________________________________________________
# title: Multi-Objective Improvement of Android Applications, author:Jamie Callan
# Downloaded 'ac9ee72a5cd611e9143e385f668af662583721ee' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/ac9ee72a5cd611e9143e385f668af662583721ee.pdf'
# _____________________________________________________________________
# title: Screen Correspondence: Mapping Interchangeable Elements between UIs, author:Jeffrey P. Bigham
# Downloaded '0e84679cf0945a2868245ba2be68c90453e48f2e' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/0e84679cf0945a2868245ba2be68c90453e48f2e.pdf'
# _____________________________________________________________________
# title: Exploring Stigmergic Collaboration and Task Modularity Through an Expert Crowdsourcing Annotation System: The Case of Storm Phenomena in the Euro-Atlantic Region, author:Jeffrey P. Bigham
# ...
# _____________________________________________________________________
# title: Genitourinary Management and Follow-Up for Patients with Stevens-Johnson Syndrome/Toxic Epidermal Necrolysis, author:Tom Michael Mitchell
# 'e98e4af918f3ad0f6ea65f2c68e2846a5b7eb333' is not open access
# _____________________________________________________________________
# title: Answering Ambiguous Questions with a Database of Questions, Answers, and Revisions, author:William W. Cohen
# Downloaded '2ca8e50ffd6e2e67f3fe2fbf1af57dbedb4cf493' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/2ca8e50ffd6e2e67f3fe2fbf1af57dbedb4cf493.pdf'
# _____________________________________________________________________
# title: MEMORY-VQ: Compression for Tractable Internet-Scale Memory, author:William W. Cohen
# Downloaded '646cca9de110726000a6e44560743b241a4d7f91' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/646cca9de110726000a6e44560743b241a4d7f91.pdf'
# _____________________________________________________________________
# title: Subject-driven Text-to-Image Generation via Apprenticeship Learning, author:William W. Cohen
# Downloaded '83b8e18488d8f31dd017ec0b26531cef4b635b36' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/83b8e18488d8f31dd017ec0b26531cef4b635b36.pdf'
# _____________________________________________________________________
# title: GLIMMER: generalized late-interaction memory reranker, author:William W. Cohen
# Downloaded 'c67099476f2b505dfd5a22c817707fad83de9994' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/c67099476f2b505dfd5a22c817707fad83de9994.pdf'
# _____________________________________________________________________
# title: PESCO: Prompt-enhanced Self Contrastive Learning for Zero-shot Text Classification, author:Yiming Yang
# Downloaded '02ce4d3f93902a94ec2b57630b77696b7f18c84a' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/02ce4d3f93902a94ec2b57630b77696b7f18c84a.pdf'
# _____________________________________________________________________
# title: Generation-driven Contrastive Self-training for Zero-shot Text Classification with Instruction-tuned GPT, author:Yiming Yang
# Downloaded '1804dc14b1cf7bbae96bf3215997e9f14425d622' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/1804dc14b1cf7bbae96bf3215997e9f14425d622.pdf'
# _____________________________________________________________________
# title: Long-tailed Extreme Multi-label Text Classification by the Retrieval of Generated Pseudo Label Descriptions, author:Yiming Yang
# Downloaded '3c92fd24ea2a49aeba4b368abe3ef13cbce40987' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/3c92fd24ea2a49aeba4b368abe3ef13cbce40987.pdf'
# _____________________________________________________________________
# title: Learning a Fourier Transform for Linear Relative Positional Encodings in Transformers, author:Yiming Yang
# Downloaded '4ce987d4f8ae0f4680808c318980d42a82b9aa89' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/4ce987d4f8ae0f4680808c318980d42a82b9aa89.pdf'
# _____________________________________________________________________
# title: Efficient Temporal Sentence Grounding in Videos with Multi-Teacher Knowledge Distillation, author:Yiming Yang
# Downloaded '846f60ef3b98590c7ad1d84727c66a08cc2258c8' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/846f60ef3b98590c7ad1d84727c66a08cc2258c8.pdf'
# _____________________________________________________________________
# title: Retrieval-Enhanced Generative Model for Large-Scale Knowledge Graph Completion, author:Yiming Yang
# Failed to download '938d2951ba3aa26f3752d489c3c044ae67d5e809': HTTPError: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/pdf/10.1145/3539618.3592052
# _____________________________________________________________________
# title: Let's Sample Step by Step: Adaptive-Consistency for Efficient Reasoning and Coding with LLMs, author:Yiming Yang
# Downloaded 'b4a6c010724f0459c9791018e34a982cf96987cf' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/b4a6c010724f0459c9791018e34a982cf96987cf.pdf'
# _____________________________________________________________________
# title: Principle-Driven Self-Alignment of Language Models from Scratch with Minimal Human Supervision, author:Yiming Yang
# Downloaded 'e01515c6138bc525f7aec30fc85f2adf028d4156' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/e01515c6138bc525f7aec30fc85f2adf028d4156.pdf'
# _____________________________________________________________________
# title: Policy Representation via Diffusion Probability Model for Reinforcement Learning, author:Yiming Yang
# Downloaded 'fe9fe9f15f24fbbb19b62bcd9a3418511a699b84' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/fe9fe9f15f24fbbb19b62bcd9a3418511a699b84.pdf'
# _____________________________________________________________________
# title: Accelerating Diffusion-based Combinatorial Optimization Solvers by Progressive Distillation, author:Yiming Yang
# Downloaded '08a23cb1ae7b0748407146520c0630d7f2b51c4c' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/08a23cb1ae7b0748407146520c0630d7f2b51c4c.pdf'
# _____________________________________________________________________
# title: Automatic synchrotron tomographic alignment schemes based on genetic algorithms and human-in-the-loop software, author:Yiming Yang
# Downloaded '0a187bee2436f4a2e98dd94d3c2f18b83281efdb' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/0a187bee2436f4a2e98dd94d3c2f18b83281efdb.pdf'
# _____________________________________________________________________
# title: High CD8+tumor-infiltrating lymphocytes indicate severe exhaustion and poor prognosis in angioimmunoblastic T-cell lymphoma, author:Yiming Yang
# Downloaded '16db1c1c00ac219984c28480cb60fd09b1897bf6' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/16db1c1c00ac219984c28480cb60fd09b1897bf6.pdf'
# _____________________________________________________________________
# title: Numerical Investigation of Fatigue Crack Propagation Behaviour of 550E High-Performance Steel, author:Yiming Yang
# Downloaded '2bfa8ac40c1ff8e45c298115fcadae062526310e' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/2bfa8ac40c1ff8e45c298115fcadae062526310e.pdf'
# _____________________________________________________________________
# title: Association between albumin-to-globulin ratio and the risk of overall survival in advanced non-small cell lung cancer patients with anlotinib treatment: a retrospective cohort study, author:Yiming Yang
# Downloaded '48bd660e0841ca990178cfafec01163ba2bb07ee' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/48bd660e0841ca990178cfafec01163ba2bb07ee.pdf'
# _____________________________________________________________________
# title: Analysis of Volatile Components in Dried Fruits and Branch Exudates of Schisandra chinensis with Different Fruit Colors Using GC-IMS Technology, author:Yiming Yang
# Downloaded '535047a5e5845b3a05fb566d9733091448410d75' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/535047a5e5845b3a05fb566d9733091448410d75.pdf'
# _____________________________________________________________________
# title: Secreted endogenous macrosomes reduce Aβ burden and ameliorate Alzheimer’s disease, author:Yiming Yang
# Failed to download '5921cc9349dfc43acfefbddc4c9b81a4b6a0b1f9': HTTPError: 403 Client Error: Forbidden for url: https://www.science.org/doi/pdf/10.1126/sciadv.ade0293?download=true
# _____________________________________________________________________
# title: DIFUSCO: Graph-based Diffusion Solvers for Combinatorial Optimization, author:Yiming Yang
# Downloaded '5f90d43e6ece5c6ee6e8186e4b57d46c85377713' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/5f90d43e6ece5c6ee6e8186e4b57d46c85377713.pdf'
# _____________________________________________________________________
# title: Balancing Exploration and Exploitation in Hierarchical Reinforcement Learning via Latent Landmark Graphs, author:Yiming Yang
# Downloaded '6a42f6362afa3a1a0936f7a6a8927d04a2285cc5' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/6a42f6362afa3a1a0936f7a6a8927d04a2285cc5.pdf'
# _____________________________________________________________________
# title: Aligning Large Multimodal Models with Factually Augmented RLHF, author:Yiming Yang
# Downloaded '844bb298d49ef4a07b5d4929dfdfd170f6a1d5f5' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/844bb298d49ef4a07b5d4929dfdfd170f6a1d5f5.pdf'
# _____________________________________________________________________
# title: An Experimental Study on Secondary Transfer Performances of Prestress after Anchoring Failure of Steel Wire Strands, author:Yiming Yang
# Downloaded 'b946ca9514be9920e5d1eff11f597facb8f7c6b7' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/b946ca9514be9920e5d1eff11f597facb8f7c6b7.pdf'
# _____________________________________________________________________
# title: MRI Features for Predicting Microvascular Invasion and Postoperative Recurrence in Hepatocellular Carcinoma Without Peritumoral Hypointensity, author:Yiming Yang
# Downloaded 'f1a75a847c99ab399454c911235f0d5f7854c5a4' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/f1a75a847c99ab399454c911235f0d5f7854c5a4.pdf'
# _____________________________________________________________________
# title: Impact of local governments’ construction land allocation strategies on innovation-driven development of China, author:Yiming Yang
# 'ff4bd0966db6a5f30fe41c8479765e9d9702a8c0' is not open access
# _____________________________________________________________________
# title: HomeRobot: Open-Vocabulary Mobile Manipulation, author:Yonatan Bisk
# Downloaded '3b0c02955e88f5862e61b560c7f70ba8cf235b1d' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/3b0c02955e88f5862e61b560c7f70ba8cf235b1d.pdf'
# _____________________________________________________________________
# title: Plan, Eliminate, and Track - Language Models are Good Teachers for Embodied Agents, author:Yonatan Bisk
# Downloaded '5ce2f1dff23a5620f77f9b11f1e534422ab8ff3f' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/5ce2f1dff23a5620f77f9b11f1e534422ab8ff3f.pdf'
# _____________________________________________________________________
# title: MOSAIC: Learning Unified Multi-Sensory Object Property Representations for Robot Perception, author:Yonatan Bisk
# Downloaded '69b8cd15966c4c9c3e44e71769e557f1c87fb3f9' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/69b8cd15966c4c9c3e44e71769e557f1c87fb3f9.pdf'
# _____________________________________________________________________
# title: Reasoning about the Unseen for Efficient Outdoor Object Navigation, author:Yonatan Bisk
# Downloaded '8035a247980cb18abf2bb7b9d96e7d4c63622ef2' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/8035a247980cb18abf2bb7b9d96e7d4c63622ef2.pdf'
# _____________________________________________________________________
# title: Understanding Ethics in NLP Authoring and Reviewing, author:Yulia Tsvetkov
# Downloaded '12902f724619344dfeae330043c4b7b1c9d99bd0' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/12902f724619344dfeae330043c4b7b1c9d99bd0.pdf'
# _____________________________________________________________________
# title: BotPercent: Estimating Twitter Bot Populations from Groups to Crowds, author:Yulia Tsvetkov
# Downloaded '1bc0dc96d745325d89ec5bee1da1541255e6d1eb' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/1bc0dc96d745325d89ec5bee1da1541255e6d1eb.pdf'
# _____________________________________________________________________
# title: Examining risks of racial biases in NLP tools for child protective services, author:Yulia Tsvetkov
# Failed to download '346e4f35a5a81ef893792133ec1fec18f23c1768': HTTPError: 403 Client Error: Forbidden for url: https://dl.acm.org/doi/pdf/10.1145/3593013.3594094
# _____________________________________________________________________
# title: Understanding In-Context Learning via Supportive Pretraining Data, author:Yulia Tsvetkov
# Downloaded '36f7bc27c9a37eb337c35df4ae86f148e13d4e9a' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/36f7bc27c9a37eb337c35df4ae86f148e13d4e9a.pdf'
# _____________________________________________________________________
# title: Assessing Language Model Deployment with Risk Cards, author:Yulia Tsvetkov
# Downloaded '49f1fa0d609ff06564b46270cbc022b7d9d195f4' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/49f1fa0d609ff06564b46270cbc022b7d9d195f4.pdf'
# _____________________________________________________________________
# title: From Pretraining Data to Language Models to Downstream Tasks: Tracking the Trails of Political Biases Leading to Unfair NLP Models, author:Yulia Tsvetkov
# Downloaded '5471114e37448bea2457b74894b1ecb92bbcfdf6' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/5471114e37448bea2457b74894b1ecb92bbcfdf6.pdf'
# _____________________________________________________________________
# title: FactKB: Generalizable Factuality Evaluation using Language Models Enhanced with Factual Knowledge, author:Yulia Tsvetkov
# Downloaded '663d743272e9ab04f54d9105a3c3a3f6e22dd1dd' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/663d743272e9ab04f54d9105a3c3a3f6e22dd1dd.pdf'
# _____________________________________________________________________
# title: TalkUp: Paving the Way for Understanding Empowering Language, author:Yulia Tsvetkov
# Downloaded '926dece297434dc535733814efca28759b94ab82' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/926dece297434dc535733814efca28759b94ab82.pdf'
# _____________________________________________________________________
# title: Trusting Your Evidence: Hallucinate Less with Context-aware Decoding, author:Yulia Tsvetkov
# Downloaded '984d4a1d41bfc8184fb77b8aa0eb8e96d536d048' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/984d4a1d41bfc8184fb77b8aa0eb8e96d536d048.pdf'
# _____________________________________________________________________
# title: BUFFET: Benchmarking Large Language Models for Few-shot Cross-lingual Transfer, author:Yulia Tsvetkov
# Downloaded 'ad454e24bd32408559512b4bac4cd5237794210f' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/ad454e24bd32408559512b4bac4cd5237794210f.pdf'
# _____________________________________________________________________
# title: Mitigating Societal Harms in Large Language Models, author:Yulia Tsvetkov
# Downloaded 'cb0335107f12d331ace2cbf220eb3c7bdcf653c5' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/cb0335107f12d331ace2cbf220eb3c7bdcf653c5.pdf'
# _____________________________________________________________________
# title: Minding Language Models’ (Lack of) Theory of Mind: A Plug-and-Play Multi-Character Belief Tracker, author:Yulia Tsvetkov
# Downloaded 'd7a3f5c612930a3c08f1632b88934252edc66d67' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/d7a3f5c612930a3c08f1632b88934252edc66d67.pdf'
# _____________________________________________________________________
# title: Can Language Models Solve Graph Problems in Natural Language?, author:Yulia Tsvetkov
# Downloaded 'df2beaae63e4d68ef8e762bcd4704c9f11f856d9' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/df2beaae63e4d68ef8e762bcd4704c9f11f856d9.pdf'
# _____________________________________________________________________
# title: LEXPLAIN: Improving Model Explanations via Lexicon Supervision, author:Yulia Tsvetkov
# Downloaded 'f9a5af5b21563b9bdd09630a8dec62d515479678' to '/Users/vashisth/Documents/GitHub/ANLP_projects/NLP-RAG/data/papers/f9a5af5b21563b9bdd09630a8dec62d515479678.pdf'

# %%
# checking num pdfs
! cd data/papers && ls | grep '\.pdf$' | wc -l
# Out:
#      290

# %%
no_failed =337-290
no_failed
# Out:
# 47

# %%
# !pip freeze
# Out:
# accelerate==0.27.2
# aiohttp==3.9.1
# aiosignal==1.3.1
# annotated-types==0.6.0
# annoy==1.17.3
# antlr4-python3-runtime==4.9.3
# anyio @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_a17a7759g2/croot/anyio_1706220182417/work
# appdirs==1.4.4
# appnope @ file:///home/conda/feedstock_root/build_artifacts/appnope_1707233003401/work
# argon2-cffi @ file:///opt/conda/conda-bld/argon2-cffi_1645000214183/work
# argon2-cffi-bindings @ file:///Users/cbousseau/work/recipes/ci_py311/argon2-cffi-bindings_1677915727169/work
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1698341106958/work
# async-lru @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_02efro5ps8/croot/async-lru_1699554529181/work
# attrs @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_224434dqzl/croot/attrs_1695717839274/work
# Babel @ file:///Users/cbousseau/work/recipes/ci_py311/babel_1677920677615/work
# backoff==2.2.1
# beautifulsoup4 @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_fa78jvo_0n/croot/beautifulsoup4-split_1681493044306/work
# bitarray==2.9.2
# bitsandbytes==0.42.0
# bleach @ file:///opt/conda/conda-bld/bleach_1641577558959/work
# blinker==1.7.0
# catalogue==2.0.10
# certifi @ file:///home/conda/feedstock_root/build_artifacts/certifi_1707022139797/work/certifi
# cffi @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_b4nang6w_y/croot/cffi_1700254307954/work
# chardet==5.2.0
# charset-normalizer==3.3.2
# click==8.1.7
# colbert-ai==0.2.19
# coloredlogs==15.0.1
# comm @ file:///home/conda/feedstock_root/build_artifacts/comm_1704278392174/work
# contourpy==1.2.0
# cryptography==42.0.4
# cycler==0.12.1
# dataclasses-json==0.6.4
# dataclasses-json-speakeasy==0.5.11
# datasets==2.17.1
# debugpy @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_563_nwtkoc/croot/debugpy_1690905063850/work
# decorator @ file:///home/conda/feedstock_root/build_artifacts/decorator_1641555617451/work
# defusedxml @ file:///tmp/build/80754af9/defusedxml_1615228127516/work
# Deprecated==1.2.14
# dill==0.3.8
# dirtyjson==1.0.8
# diskcache==5.6.3
# distro==1.9.0
# docker-pycreds==0.4.0
# effdet==0.4.1
# emoji==2.10.1
# et-xmlfile==1.1.0
# exceptiongroup @ file:///home/conda/feedstock_root/build_artifacts/exceptiongroup_1704921103267/work
# executing @ file:///home/conda/feedstock_root/build_artifacts/executing_1698579936712/work
# faiss-cpu==1.7.4
# fastjsonschema @ file:///Users/cbousseau/work/recipes/ci_py311_2/python-fastjsonschema_1678996913062/work
# filelock==3.0.12
# filetype==1.2.0
# Flask==3.0.2
# flatbuffers==23.5.26
# fonttools==4.49.0
# frozenlist==1.4.1
# fsspec==2023.10.0
# git-python==1.0.3
# gitdb==4.0.11
# GitPython==3.1.41
# greenlet==3.0.3
# h11==0.14.0
# httpcore==1.0.3
# httpx==0.26.0
# huggingface-hub==0.20.3
# humanfriendly==10.0
# idna @ file:///Users/cbousseau/work/recipes/ci_py311/idna_1677906072337/work
# importlib-metadata==3.7.0
# inquirerpy==0.3.4
# iopath==0.1.10
# ipykernel @ file:///Users/runner/miniforge3/conda-bld/ipykernel_1707326353119/work
# ipython @ file:///home/conda/feedstock_root/build_artifacts/ipython_1706795662110/work
# ipywidgets @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_f07ugy1hvo/croot/ipywidgets_1679394821999/work
# itsdangerous==2.1.2
# jedi @ file:///home/conda/feedstock_root/build_artifacts/jedi_1696326070614/work
# Jinja2 @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_7dognxkzoy/croot/jinja2_1706733627811/work
# joblib==1.3.2
# json5 @ file:///tmp/build/80754af9/json5_1624432770122/work
# jsonpatch==1.33
# jsonpath-python==1.0.6
# jsonpointer==2.4
# jsonschema @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_27o3go8sqa/croot/jsonschema_1699041627313/work
# jsonschema-specifications @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_d38pclgu95/croot/jsonschema-specifications_1699032390832/work
# jupyter @ file:///Users/cbousseau/work/recipes/ci_py311/jupyter_1677932849424/work
# jupyter-console @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_62liw5pns2/croot/jupyter_console_1679999641189/work
# jupyter-events @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_14ldd9s4d0/croot/jupyter_events_1699282481406/work
# jupyter-lsp @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_ae9br5v37x/croot/jupyter-lsp-meta_1699978259353/work
# jupyter_client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1699283905679/work
# jupyter_core @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_782yoyc_98/croot/jupyter_core_1698937318631/work
# jupyter_server @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_281pz9vly5/croot/jupyter_server_1699466465530/work
# jupyter_server_terminals @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_e7ryd60iuw/croot/jupyter_server_terminals_1686870731283/work
# jupyterlab @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_e2r14w4wga/croot/jupyterlab_1706802597734/work
# jupyterlab-pygments @ file:///tmp/build/80754af9/jupyterlab_pygments_1601490720602/work
# jupyterlab-widgets @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_b3iojkjor2/croot/jupyterlab_widgets_1700168642873/work
# jupyterlab_server @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_315a64u22w/croot/jupyterlab_server_1699555438434/work
# kiwisolver==1.4.5
# langchain==0.1.9
# langchain-community==0.0.24
# langchain-core==0.1.26
# langdetect==1.0.9
# langsmith==0.1.6
# layoutparser==0.3.4
# llama-index==0.9.48
# llvmlite==0.42.0
# lxml==5.1.0
# Markdown==3.5.2
# MarkupSafe==2.1.5
# marshmallow==3.20.2
# matplotlib==3.8.3
# matplotlib-inline @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-inline_1660814786464/work
# mistune @ file:///Users/cbousseau/work/recipes/ci_py311/mistune_1677916600725/work
# mpmath==1.3.0
# msg-parser==1.2.0
# multidict==6.0.5
# multiprocess==0.70.16
# mypy-extensions==1.0.0
# nbclient @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_626hpwnurm/croot/nbclient_1698934218848/work
# nbconvert @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_caxv2emy33/croot/nbconvert_1699022756174/work
# nbformat @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_cbnf5nccgk/croot/nbformat_1694616744196/work
# nest_asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1705850609492/work
# networkx==3.2.1
# ninja==1.11.1.1
# nltk==3.8.1
# notebook @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_d3ves7gv_b/croot/notebook_1700582112788/work
# notebook_shim @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_d6_ze10f45/croot/notebook-shim_1699455897525/work
# numba==0.59.0
# numpy==1.26.4
# olefile==0.47
# omegaconf==2.3.0
# onnx==1.15.0
# onnxruntime==1.15.1
# openai==1.12.0
# opencv-python==4.9.0.80
# openpyxl==3.1.2
# orjson==3.9.15
# overrides @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_70s80guh9g/croot/overrides_1699371144462/work
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1696202382185/work
# pacmap==0.7.2
# pandas==2.2.0
# pandocfilters @ file:///opt/conda/conda-bld/pandocfilters_1643405455980/work
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1638334955874/work
# pdf2image==1.17.0
# pdfminer.six==20221105
# pdfplumber==0.10.4
# pexpect @ file:///home/conda/feedstock_root/build_artifacts/pexpect_1706113125309/work
# pfzy==0.3.4
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# pikepdf==8.13.0
# pillow==10.2.0
# pillow_heif==0.15.0
# platformdirs @ file:///home/conda/feedstock_root/build_artifacts/platformdirs_1706713388748/work
# plotly==5.19.0
# ply==3.11
# portalocker==2.8.2
# prometheus-client @ file:///Users/cbousseau/work/recipes/ci_py311_2/prometheus_client_1678996808082/work
# prompt-toolkit @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_c63v4kqjzr/croot/prompt-toolkit_1704404354115/work
# protobuf==4.25.2
# psutil @ file:///Users/cbousseau/work/recipes/ci_py311_2/psutil_1678995687212/work
# ptyprocess @ file:///home/conda/feedstock_root/build_artifacts/ptyprocess_1609419310487/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# pure-eval @ file:///home/conda/feedstock_root/build_artifacts/pure_eval_1642875951954/work
# pyarrow==15.0.0
# pyarrow-hotfix==0.6
# pycocotools==2.0.7
# pycparser @ file:///tmp/build/80754af9/pycparser_1636541352034/work
# pydantic==2.6.2
# pydantic_core==2.16.3
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1700607939962/work
# pypandoc==1.13
# pyparsing==3.1.1
# pypdf==4.0.2
# pypdfium2==4.27.0
# PyQt5==5.15.10
# PyQt5-sip @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_7c_9f71up5/croot/pyqt-split_1698769091879/work/pyqt_sip
# pytesseract==0.3.10
# python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1626286286081/work
# python-docx==1.1.0
# python-dotenv==1.0.1
# python-iso639==2024.2.7
# python-json-logger @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_c3baq2ko4j/croot/python-json-logger_1683823815343/work
# python-magic==0.4.27
# python-multipart==0.0.9
# python-pptx==0.6.23
# pytz @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_6btwyyj8a1/croot/pytz_1695131592184/work
# PyYAML @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_a8_sdgulmz/croot/pyyaml_1698096054705/work
# pyzmq @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_43pxpbos3z/croot/pyzmq_1705605108344/work
# qtconsole @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_90dkxmzj63/croot/qtconsole_1700160657014/work
# QtPy @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_7ctc7lxlar/croot/qtpy_1700144861044/work
# RAGatouille==0.0.7.post5
# rapidfuzz==3.6.1
# referencing @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_5cz64gsx70/croot/referencing_1699012046031/work
# regex==2023.12.25
# requests @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_b3tnputioh/croot/requests_1707355573919/work
# rfc3339-validator @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_76ae5cu30h/croot/rfc3339-validator_1683077051957/work
# rfc3986-validator @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_d0l5zd97kt/croot/rfc3986-validator_1683058998431/work
# rpds-py @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_f8jkozoefm/croot/rpds-py_1698945944860/work
# ruff==0.1.15
# safetensors==0.4.2
# scikit-learn==1.2.2
# scipy==1.12.0
# semanticscholar==0.7.0
# Send2Trash @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_5b31f0zzlv/croot/send2trash_1699371144121/work
# sentence-transformers==2.4.0
# sentencepiece==0.1.99
# sentry-sdk==1.40.4
# setproctitle==1.3.3
# sip @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_ba9odc_3u1/croot/sip_1698675938651/work
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1620240208055/work
# smmap==5.0.1
# sniffio @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_1573pknjrg/croot/sniffio_1705431298885/work
# soupsieve @ file:///private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_9798xzs_03/croot/soupsieve_1696347567192/work
# SQLAlchemy==2.0.27
# srsly==2.4.8
# stack-data @ file:///home/conda/feedstock_root/build_artifacts/stack_data_1669632077133/work
# sympy==1.12
# tabulate==0.9.0
# tenacity==8.2.3
# terminado @ file:///Users/cbousseau/work/recipes/ci_py311/terminado_1677918849903/work
# threadpoolctl==3.2.0
# tiktoken==0.6.0
# timm==0.9.16
# tinycss2 @ file:///Users/cbousseau/work/recipes/ci_py311/tinycss2_1677917352983/work
# tokenizers==0.15.2
# torch==2.1.2
# torchaudio==2.1.2
# torchvision==0.16.2
# tornado @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_3a5nrn2jeh/croot/tornado_1696936974091/work
# tqdm==4.66.1
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1704212992681/work
# transformers==4.38.0
# typing==3.7.4.3
# typing-inspect==0.9.0
# typing_extensions @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_6ejdc7ufhc/croot/typing_extensions_1705599306111/work
# tzdata==2024.1
# ujson==5.9.0
# unicode==2.9
# Unidecode==1.3.8
# unstructured==0.12.4
# unstructured-client==0.18.0
# unstructured-inference==0.7.23
# unstructured.pytesseract==0.3.12
# urllib3 @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_11wy4ndttf/croot/urllib3_1700840488804/work
# voyager==2.0.2
# wandb==0.16.3
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1704731205417/work
# webencodings==0.5.1
# websocket-client @ file:///Users/cbousseau/work/recipes/ci_py311/websocket-client_1677918996745/work
# Werkzeug==3.0.1
# widgetsnbextension @ file:///private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_cd_nvw5x1_/croot/widgetsnbextension_1679313872684/work
# wrapt==1.16.0
# xlrd==2.0.1
# XlsxWriter==3.2.0
# xxhash==3.4.1
# yarl==1.9.4
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1695255097490/work

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
# %cd drive/MyDrive/ANLP/NLP-RAG/src-rag
# !ls

# %%
import os
# from dotenv import load_dotenv
# load_dotenv('.env')
# hf_api = os.getenv('HF_API')

# %%
pip install transformers==4.38.0
# Out:
# Requirement already satisfied: transformers==4.38.0 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (4.38.0)
# Requirement already satisfied: filelock in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (3.0.12)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (2023.12.25)
# Requirement already satisfied: requests in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from transformers==4.38.0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.0) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from requests->transformers==4.38.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from requests->transformers==4.38.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from requests->transformers==4.38.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (from requests->transformers==4.38.0) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -q torch accelerate bitsandbytes langchain sentence-transformers faiss-cpu openpyxl
# !pip install -q torch accelerate bitsandbytes langchain sentence-transformers faiss-gpu openpyxl

# %%
# !pip install unstructured ragatouille
# # reranker
# from ragatouille import RAGPretrainedModel

# %%
# # this will take time :c
# !CUDACXX=/usr/local/cuda-12/bin/nvcc CMAKE_ARGS="-DLLAMA_CUBLAS=on -DCMAKE_CUDA_ARCHITECTURES=all-major" FORCE_CMAKE=1 pip install llama-cpp-python --no-cache-dir --force-reinstall --upgrade

# %%
# !pip install ctransformers[cuda]

# %%
# !pip3 install numpy==1.26.4
import numpy as np
np.__version__
# Out:
# Requirement already satisfied: numpy==1.26.4 in /Users/vashisth/anaconda3/envs/llama_hw/lib/python3.11/site-packages (1.26.4)
# '1.26.4'

# %%
# fix colab error: https://stackoverflow.com/questions/56081324/why-are-google-colab-shell-commands-not-working
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.docstore.document import Document as LangchainDocument
from langchain.chains.summarize import load_summarize_chain
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.llms import LlamaCpp
from langchain.prompts import PromptTemplate, ChatPromptTemplate
import os
import pandas as pd

# %%
from huggingface_hub import hf_hub_download
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# %%
from langchain.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from tqdm.notebook import tqdm
import pandas as pd
from typing import Optional, List, Tuple
import matplotlib.pyplot as plt
pd.set_option(
    "display.max_colwidth", None
)

# %%
# pip list --outdated

# %% [markdown]
# # Specify the model/versions, etc.
# ## also specify the knowledge base file and the reference answer directory

# %%
QUESTIONS_FILE = '../data/test/questions.txt' # change when we have all the test ones / for the category wise performance analysis
EMBEDDING_MODEL = "thenlper/gte-base"
RERANKER_MODEL = "colbert-ir/colbertv2.0"
# RERANKER = RAGPretrainedModel.from_pretrained(RERANKER_MODEL)

# %%
EMBEDDING_MODEL_NAME = EMBEDDING_MODEL
embedding_model = HuggingFaceEmbeddings(
    model_name=EMBEDDING_MODEL_NAME,
    multi_process=True,
    # model_kwargs={"device": "cuda"},
    encode_kwargs={"normalize_embeddings": True},
)

# %% [markdown]
# # Running on processed schedule files

# %%
from langchain_community.document_loaders import TextLoader, CSVLoader
import glob
from database import split_documents, create_db
directory_csv = '../data/schedule_csv/'
csv_files = glob.glob(os.path.join(directory_csv, '**', '*.csv'), recursive=True)

# %%
len(csv_files)
# Out:
# 4

# %%
loader_csv = DirectoryLoader(directory_csv, glob="**/*.csv",
                             use_multithreading = True,
                             loader_cls=CSVLoader,
                            #  loader_kwargs = csv_args
                             )
docs_csv = loader_csv.load()
docs_csv
# Out:
# [Document(page_content='Question: What is the course number of IDeATe: Introduction to 3D Animation Pipeline?\nAnswer: 60125', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 0}),
#  Document(page_content='Question: What is the name of course number 60125?\nAnswer: IDeATe: Introduction to 3D Animation Pipeline', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 1}),
#  Document(page_content='Question: What time does the course 60125 IDeATe: Introduction to 3D Animation Pipeline begin?\nAnswer: 12:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 2}),
#  Document(page_content='Question: What time does the course 60125 IDeATe: Introduction to 3D Animation Pipeline end?\nAnswer: 01:50PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 3}),
#  Document(page_content='Question: What days does the course 60125 IDeATe: Introduction to 3D Animation Pipeline meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 4}),
#  Document(page_content='Question: What is the location of the course 60125 IDeATe: Introduction to 3D Animation Pipeline?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 5}),
#  Document(page_content='Question: What is the building and room number of the course 60125 IDeATe: Introduction to 3D Animation Pipeline?\nAnswer: CMU REMOTE', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 6}),
#  Document(page_content='Question: How many units is the course 60125 IDeATe: Introduction to 3D Animation Pipeline?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 7}),
#  Document(page_content='Question: Who are the instructors of the course 60125 IDeATe: Introduction to 3D Animation Pipeline?\nAnswer: Mahler', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 8}),
#  Document(page_content='Question: What is the course number of Basic Science to Modern Medicine?\nAnswer: 03132', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 9}),
#  Document(page_content='Question: What is the name of course number 03132?\nAnswer: Basic Science to Modern Medicine', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 10}),
#  Document(page_content='Question: What time does the course 03132 Basic Science to Modern Medicine begin?\nAnswer: 02:00PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 11}),
#  Document(page_content='Question: What time does the course 03132 Basic Science to Modern Medicine end?\nAnswer: 03:20PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 12}),
#  Document(page_content='Question: What days does the course 03132 Basic Science to Modern Medicine meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 13}),
#  Document(page_content='Question: What is the location of the course 03132 Basic Science to Modern Medicine?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 14}),
#  Document(page_content='Question: What is the building and room number of the course 03132 Basic Science to Modern Medicine?\nAnswer: CMU REMOTE', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 15}),
#  Document(page_content='Question: How many units is the course 03132 Basic Science to Modern Medicine?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 16}),
#  Document(page_content='Question: Who are the instructors of the course 03132 Basic Science to Modern Medicine?\nAnswer: Mccartney', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 17}),
#  Document(page_content='Question: What is the course number of Tissue Engineering?\nAnswer: 42882', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 18}),
#  Document(page_content='Question: What is the name of course number 42882?\nAnswer: Tissue Engineering', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 19}),
#  Document(page_content='Question: What time does the course 42882 Tissue Engineering begin?\nAnswer: 07:00PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 20}),
#  Document(page_content='Question: What time does the course 42882 Tissue Engineering end?\nAnswer: 08:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 21}),
#  Document(page_content='Question: What days does the course 42882 Tissue Engineering meet?\nAnswer: Wednesday,', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 22}),
#  Document(page_content='Question: What is the location of the course 42882 Tissue Engineering?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 23}),
#  Document(page_content='Question: What is the building and room number of the course 42882 Tissue Engineering?\nAnswer: CMU REMOTE', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 24}),
#  Document(page_content='Question: How many units is the course 42882 Tissue Engineering?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 25}),
#  Document(page_content='Question: Who are the instructors of the course 42882 Tissue Engineering?\nAnswer: Palchesko', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 26}),
#  Document(page_content='Question: What is the course number of Organizational Behavior?\nAnswer: 70311', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 27}),
#  Document(page_content='Question: What is the name of course number 70311?\nAnswer: Organizational Behavior', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 28}),
#  Document(page_content='Question: What time does the course 70311 Organizational Behavior begin?\nAnswer: 09:30AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 29}),
#  Document(page_content='Question: What time does the course 70311 Organizational Behavior end?\nAnswer: 10:50AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 30}),
#  Document(page_content='Question: What days does the course 70311 Organizational Behavior meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 31}),
#  Document(page_content='Question: What is the location of the course 70311 Organizational Behavior?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 32}),
#  Document(page_content='Question: What is the building and room number of the course 70311 Organizational Behavior?\nAnswer: TEP 2612', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 33}),
#  Document(page_content='Question: How many units is the course 70311 Organizational Behavior?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 34}),
#  Document(page_content='Question: Who are the instructors of the course 70311 Organizational Behavior?\nAnswer: Zhang', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 35}),
#  Document(page_content='Question: What is the course number of Organic Chemistry I?\nAnswer: 09217', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 36}),
#  Document(page_content='Question: What is the name of course number 09217?\nAnswer: Organic Chemistry I', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 37}),
#  Document(page_content='Question: What time does the course 09217 Organic Chemistry I begin?\nAnswer: 09:30AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 38}),
#  Document(page_content='Question: What time does the course 09217 Organic Chemistry I end?\nAnswer: 10:50AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 39}),
#  Document(page_content='Question: What days does the course 09217 Organic Chemistry I meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 40}),
#  Document(page_content='Question: What is the location of the course 09217 Organic Chemistry I?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 41}),
#  Document(page_content='Question: What is the building and room number of the course 09217 Organic Chemistry I?\nAnswer: DH 2302', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 42}),
#  Document(page_content='Question: How many units is the course 09217 Organic Chemistry I?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 43}),
#  Document(page_content='Question: Who are the instructors of the course 09217 Organic Chemistry I?\nAnswer: Silva', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 44}),
#  Document(page_content='Question: What is the course number of Principles of Functional Programming?\nAnswer: 15150', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 45}),
#  Document(page_content='Question: What is the name of course number 15150?\nAnswer: Principles of Functional Programming', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 46}),
#  Document(page_content='Question: What time does the course 15150 Principles of Functional Programming begin?\nAnswer: 11:00AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 47}),
#  Document(page_content='Question: What time does the course 15150 Principles of Functional Programming end?\nAnswer: 12:20PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 48}),
#  Document(page_content='Question: What days does the course 15150 Principles of Functional Programming meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 49}),
#  Document(page_content='Question: What is the location of the course 15150 Principles of Functional Programming?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 50}),
#  Document(page_content='Question: What is the building and room number of the course 15150 Principles of Functional Programming?\nAnswer: GHC CLSTR', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 51}),
#  Document(page_content='Question: How many units is the course 15150 Principles of Functional Programming?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 52}),
#  Document(page_content='Question: Who are the instructors of the course 15150 Principles of Functional Programming?\nAnswer: Instructor TBA', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 53}),
#  Document(page_content='Question: What is the course number of Topics of Law: Introduction to Intellectual Property Law?\nAnswer: 66221', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 54}),
#  Document(page_content='Question: What is the name of course number 66221?\nAnswer: Topics of Law: Introduction to Intellectual Property Law', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 55}),
#  Document(page_content='Question: What time does the course 66221 Topics of Law: Introduction to Intellectual Property Law begin?\nAnswer: 06:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 56}),
#  Document(page_content='Question: What time does the course 66221 Topics of Law: Introduction to Intellectual Property Law end?\nAnswer: 09:50PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 57}),
#  Document(page_content='Question: What days does the course 66221 Topics of Law: Introduction to Intellectual Property Law meet?\nAnswer: Tuesday, Thursday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 58}),
#  Document(page_content='Question: What is the location of the course 66221 Topics of Law: Introduction to Intellectual Property Law?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 59}),
#  Document(page_content='Question: What is the building and room number of the course 66221 Topics of Law: Introduction to Intellectual Property Law?\nAnswer: CMU REMOTE', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 60}),
#  Document(page_content='Question: How many units is the course 66221 Topics of Law: Introduction to Intellectual Property Law?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 61}),
#  Document(page_content='Question: Who are the instructors of the course 66221 Topics of Law: Introduction to Intellectual Property Law?\nAnswer: Patel, Thomas', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 62}),
#  Document(page_content='Question: What is the course number of Acting for Non-Majors?\nAnswer: 54191', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 63}),
#  Document(page_content='Question: What is the name of course number 54191?\nAnswer: Acting for Non-Majors', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 64}),
#  Document(page_content='Question: What time does the course 54191 Acting for Non-Majors begin?\nAnswer: 11:00AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 65}),
#  Document(page_content='Question: What time does the course 54191 Acting for Non-Majors end?\nAnswer: 12:20PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 66}),
#  Document(page_content='Question: What days does the course 54191 Acting for Non-Majors meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 67}),
#  Document(page_content='Question: What is the location of the course 54191 Acting for Non-Majors?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 68}),
#  Document(page_content='Question: What is the building and room number of the course 54191 Acting for Non-Majors?\nAnswer: PCA 321', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 69}),
#  Document(page_content='Question: How many units is the course 54191 Acting for Non-Majors?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 70}),
#  Document(page_content='Question: Who are the instructors of the course 54191 Acting for Non-Majors?\nAnswer: Instructor TBA', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 71}),
#  Document(page_content='Question: What is the course number of Introduction to Computer Systems?\nAnswer: 18213', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 72}),
#  Document(page_content='Question: What is the name of course number 18213?\nAnswer: Introduction to Computer Systems', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 73}),
#  Document(page_content='Question: What time does the course 18213 Introduction to Computer Systems begin?\nAnswer: 09:30AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 74}),
#  Document(page_content='Question: What time does the course 18213 Introduction to Computer Systems end?\nAnswer: 10:50AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 75}),
#  Document(page_content='Question: What days does the course 18213 Introduction to Computer Systems meet?\nAnswer: Tuesday, Wednesday, Thursday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 76}),
#  Document(page_content='Question: What is the location of the course 18213 Introduction to Computer Systems?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 77}),
#  Document(page_content='Question: What is the building and room number of the course 18213 Introduction to Computer Systems?\nAnswer: CMU REMOTE', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 78}),
#  Document(page_content='Question: How many units is the course 18213 Introduction to Computer Systems?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 79}),
#  Document(page_content='Question: Who are the instructors of the course 18213 Introduction to Computer Systems?\nAnswer: Kesden', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 80}),
#  Document(page_content='Question: What is the course number of Foundations of Computer Systems?\nAnswer: 18613', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 81}),
#  Document(page_content='Question: What is the name of course number 18613?\nAnswer: Foundations of Computer Systems', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 82}),
#  Document(page_content='Question: What time does the course 18613 Foundations of Computer Systems begin?\nAnswer: 09:30AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 83}),
#  Document(page_content='Question: What time does the course 18613 Foundations of Computer Systems end?\nAnswer: 10:50AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 84}),
#  Document(page_content='Question: What days does the course 18613 Foundations of Computer Systems meet?\nAnswer: Tuesday, Wednesday, Thursday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 85}),
#  Document(page_content='Question: What is the location of the course 18613 Foundations of Computer Systems?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 86}),
#  Document(page_content='Question: What is the building and room number of the course 18613 Foundations of Computer Systems?\nAnswer: CMU REMOTE', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 87}),
#  Document(page_content='Question: How many units is the course 18613 Foundations of Computer Systems?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 88}),
#  Document(page_content='Question: Who are the instructors of the course 18613 Foundations of Computer Systems?\nAnswer: Kesden', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 89}),
#  Document(page_content='Question: What is the course number of Introduction to Gender Studies?\nAnswer: 76241', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 90}),
#  Document(page_content='Question: What is the name of course number 76241?\nAnswer: Introduction to Gender Studies', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 91}),
#  Document(page_content='Question: What time does the course 76241 Introduction to Gender Studies begin?\nAnswer: 09:30AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 92}),
#  Document(page_content='Question: What time does the course 76241 Introduction to Gender Studies end?\nAnswer: 10:50AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 93}),
#  Document(page_content='Question: What days does the course 76241 Introduction to Gender Studies meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 94}),
#  Document(page_content='Question: What is the location of the course 76241 Introduction to Gender Studies?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 95}),
#  Document(page_content='Question: What is the building and room number of the course 76241 Introduction to Gender Studies?\nAnswer: CMU REMOTE', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 96}),
#  Document(page_content='Question: How many units is the course 76241 Introduction to Gender Studies?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 97}),
#  Document(page_content='Question: Who are the instructors of the course 76241 Introduction to Gender Studies?\nAnswer: Aguiar', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 98}),
#  Document(page_content='Question: What is the course number of METALS Project 2?\nAnswer: 05682', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 99}),
#  Document(page_content='Question: What is the name of course number 05682?\nAnswer: METALS Project 2', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 100}),
#  Document(page_content='Question: What time does the course 05682 METALS Project 2 begin?\nAnswer: 03:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 101}),
#  Document(page_content='Question: What time does the course 05682 METALS Project 2 end?\nAnswer: 05:20PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 102}),
#  Document(page_content='Question: What days does the course 05682 METALS Project 2 meet?\nAnswer: Wednesday,', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 103}),
#  Document(page_content='Question: What is the location of the course 05682 METALS Project 2?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 104}),
#  Document(page_content='Question: What is the building and room number of the course 05682 METALS Project 2?\nAnswer: TEP 1403', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 105}),
#  Document(page_content='Question: How many units is the course 05682 METALS Project 2?\nAnswer: 48.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 106}),
#  Document(page_content='Question: Who are the instructors of the course 05682 METALS Project 2?\nAnswer: McLaren, Koedinger', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 107}),
#  Document(page_content='Question: What is the course number of Healthcare Analytics and Big Data?\nAnswer: 67357', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 108}),
#  Document(page_content='Question: What is the name of course number 67357?\nAnswer: Healthcare Analytics and Big Data', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 109}),
#  Document(page_content='Question: What time does the course 67357 Healthcare Analytics and Big Data begin?\nAnswer: 11:00AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 110}),
#  Document(page_content='Question: What time does the course 67357 Healthcare Analytics and Big Data end?\nAnswer: 12:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 111}),
#  Document(page_content='Question: What days does the course 67357 Healthcare Analytics and Big Data meet?\nAnswer: Sunday, Monday, Tuesday, Wednesday, Thursday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 112}),
#  Document(page_content='Question: What is the location of the course 67357 Healthcare Analytics and Big Data?\nAnswer: Doha, Qatar', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 113}),
#  Document(page_content='Question: What is the building and room number of the course 67357 Healthcare Analytics and Big Data?\nAnswer: CMB 2062', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 114}),
#  Document(page_content='Question: How many units is the course 67357 Healthcare Analytics and Big Data?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 115}),
#  Document(page_content='Question: Who are the instructors of the course 67357 Healthcare Analytics and Big Data?\nAnswer: Liginlal', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 116}),
#  Document(page_content='Question: What is the course number of Network Defense?\nAnswer: 95564', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 117}),
#  Document(page_content='Question: What is the name of course number 95564?\nAnswer: Network Defense', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 118}),
#  Document(page_content='Question: What time does the course 95564 Network Defense begin?\nAnswer: 03:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 119}),
#  Document(page_content='Question: What time does the course 95564 Network Defense end?\nAnswer: 05:00PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 120}),
#  Document(page_content='Question: What days does the course 95564 Network Defense meet?\nAnswer: Monday, Wednesday,', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 121}),
#  Document(page_content='Question: What is the location of the course 95564 Network Defense?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 122}),
#  Document(page_content='Question: What is the building and room number of the course 95564 Network Defense?\nAnswer: HBH 1006', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 123}),
#  Document(page_content='Question: How many units is the course 95564 Network Defense?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 124}),
#  Document(page_content='Question: Who are the instructors of the course 95564 Network Defense?\nAnswer: Meyer', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 125}),
#  Document(page_content='Question: What is the course number of Data Management and Security?\nAnswer: 95568', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 126}),
#  Document(page_content='Question: What is the name of course number 95568?\nAnswer: Data Management and Security', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 127}),
#  Document(page_content='Question: What time does the course 95568 Data Management and Security begin?\nAnswer: 03:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 128}),
#  Document(page_content='Question: What time does the course 95568 Data Management and Security end?\nAnswer: 05:00PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 129}),
#  Document(page_content='Question: What days does the course 95568 Data Management and Security meet?\nAnswer: Tuesday, Thursday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 130}),
#  Document(page_content='Question: What is the location of the course 95568 Data Management and Security?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 131}),
#  Document(page_content='Question: What is the building and room number of the course 95568 Data Management and Security?\nAnswer: HBH 1004', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 132}),
#  Document(page_content='Question: How many units is the course 95568 Data Management and Security?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 133}),
#  Document(page_content='Question: Who are the instructors of the course 95568 Data Management and Security?\nAnswer: Sooriamurthi', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 134}),
#  Document(page_content='Question: What is the course number of MITS Capstone Project?\nAnswer: 84781', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 135}),
#  Document(page_content='Question: What is the name of course number 84781?\nAnswer: MITS Capstone Project', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 136}),
#  Document(page_content='Question: What time does the course 84781 MITS Capstone Project begin?\nAnswer: 10:00AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 137}),
#  Document(page_content='Question: What time does the course 84781 MITS Capstone Project end?\nAnswer: 10:50AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 138}),
#  Document(page_content='Question: What days does the course 84781 MITS Capstone Project meet?\nAnswer: Monday,', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 139}),
#  Document(page_content='Question: What is the location of the course 84781 MITS Capstone Project?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 140}),
#  Document(page_content='Question: What is the building and room number of the course 84781 MITS Capstone Project?\nAnswer: PH A19', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 141}),
#  Document(page_content='Question: How many units is the course 84781 MITS Capstone Project?\nAnswer: 36.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 142}),
#  Document(page_content='Question: Who are the instructors of the course 84781 MITS Capstone Project?\nAnswer: Gardner', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 143}),
#  Document(page_content='Question: What is the course number of Innovation of Services & Experiences?\nAnswer: 49601', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 144}),
#  Document(page_content='Question: What is the name of course number 49601?\nAnswer: Innovation of Services & Experiences', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 145}),
#  Document(page_content='Question: What time does the course 49601 Innovation of Services & Experiences begin?\nAnswer: 08:00PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 146}),
#  Document(page_content='Question: What time does the course 49601 Innovation of Services & Experiences end?\nAnswer: 09:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 147}),
#  Document(page_content='Question: What days does the course 49601 Innovation of Services & Experiences meet?\nAnswer: Thursday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 148}),
#  Document(page_content='Question: What is the location of the course 49601 Innovation of Services & Experiences?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 149}),
#  Document(page_content='Question: What is the building and room number of the course 49601 Innovation of Services & Experiences?\nAnswer: TBA', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 150}),
#  Document(page_content='Question: How many units is the course 49601 Innovation of Services & Experiences?\nAnswer: 10.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 151}),
#  Document(page_content='Question: Who are the instructors of the course 49601 Innovation of Services & Experiences?\nAnswer: Zlotnikov', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 152}),
#  Document(page_content='Question: What is the course number of Cyber-Physical Product Design?\nAnswer: 49603', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 153}),
#  Document(page_content='Question: What is the name of course number 49603?\nAnswer: Cyber-Physical Product Design', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 154}),
#  Document(page_content='Question: What time does the course 49603 Cyber-Physical Product Design begin?\nAnswer: 08:00PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 155}),
#  Document(page_content='Question: What time does the course 49603 Cyber-Physical Product Design end?\nAnswer: 09:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 156}),
#  Document(page_content='Question: What days does the course 49603 Cyber-Physical Product Design meet?\nAnswer: Tuesday,', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 157}),
#  Document(page_content='Question: What is the location of the course 49603 Cyber-Physical Product Design?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 158}),
#  Document(page_content='Question: What is the building and room number of the course 49603 Cyber-Physical Product Design?\nAnswer: TBA', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 159}),
#  Document(page_content='Question: How many units is the course 49603 Cyber-Physical Product Design?\nAnswer: 10.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 160}),
#  Document(page_content='Question: Who are the instructors of the course 49603 Cyber-Physical Product Design?\nAnswer: Instructor TBA', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 161}),
#  Document(page_content='Question: What is the course number of Introduction to Machine Learning (Undergrad)?\nAnswer: 10301', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 162}),
#  Document(page_content='Question: What is the name of course number 10301?\nAnswer: Introduction to Machine Learning (Undergrad)', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 163}),
#  Document(page_content='Question: What time does the course 10301 Introduction to Machine Learning (Undergrad) begin?\nAnswer: 09:30AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 164}),
#  Document(page_content='Question: What time does the course 10301 Introduction to Machine Learning (Undergrad) end?\nAnswer: 10:50AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 165}),
#  Document(page_content='Question: What days does the course 10301 Introduction to Machine Learning (Undergrad) meet?\nAnswer: Monday, Tuesday, Wednesday, Thursday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 166}),
#  Document(page_content='Question: What is the location of the course 10301 Introduction to Machine Learning (Undergrad)?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 167}),
#  Document(page_content='Question: What is the building and room number of the course 10301 Introduction to Machine Learning (Undergrad)?\nAnswer: SH 105', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 168}),
#  Document(page_content='Question: How many units is the course 10301 Introduction to Machine Learning (Undergrad)?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 169}),
#  Document(page_content='Question: Who are the instructors of the course 10301 Introduction to Machine Learning (Undergrad)?\nAnswer: Chai', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 170}),
#  Document(page_content='Question: What is the course number of Integral Calculus?\nAnswer: 21112', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 171}),
#  Document(page_content='Question: What is the name of course number 21112?\nAnswer: Integral Calculus', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 172}),
#  Document(page_content='Question: What time does the course 21112 Integral Calculus begin?\nAnswer: 09:00AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 173}),
#  Document(page_content='Question: What time does the course 21112 Integral Calculus end?\nAnswer: 10:30AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 174}),
#  Document(page_content='Question: What days does the course 21112 Integral Calculus meet?\nAnswer: Sunday, Monday, Tuesday, Wednesday, Thursday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 175}),
#  Document(page_content='Question: What is the location of the course 21112 Integral Calculus?\nAnswer: Doha, Qatar', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 176}),
#  Document(page_content='Question: What is the building and room number of the course 21112 Integral Calculus?\nAnswer: TBA', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 177}),
#  Document(page_content='Question: How many units is the course 21112 Integral Calculus?\nAnswer: 10.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 178}),
#  Document(page_content='Question: Who are the instructors of the course 21112 Integral Calculus?\nAnswer: Instructor TBA', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 179}),
#  Document(page_content='Question: What is the course number of Concepts of Mathematics?\nAnswer: 21127', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 180}),
#  Document(page_content='Question: What is the name of course number 21127?\nAnswer: Concepts of Mathematics', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 181}),
#  Document(page_content='Question: What time does the course 21127 Concepts of Mathematics begin?\nAnswer: 11:00AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 182}),
#  Document(page_content='Question: What time does the course 21127 Concepts of Mathematics end?\nAnswer: 12:20PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 183}),
#  Document(page_content='Question: What days does the course 21127 Concepts of Mathematics meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 184}),
#  Document(page_content='Question: What is the location of the course 21127 Concepts of Mathematics?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 185}),
#  Document(page_content='Question: What is the building and room number of the course 21127 Concepts of Mathematics?\nAnswer: SH 105', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 186}),
#  Document(page_content='Question: How many units is the course 21127 Concepts of Mathematics?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 187}),
#  Document(page_content='Question: Who are the instructors of the course 21127 Concepts of Mathematics?\nAnswer: Abdelghany', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 188}),
#  Document(page_content='Question: What is the course number of Calculus in Three Dimensions?\nAnswer: 21259', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 189}),
#  Document(page_content='Question: What is the name of course number 21259?\nAnswer: Calculus in Three Dimensions', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 190}),
#  Document(page_content='Question: What time does the course 21259 Calculus in Three Dimensions begin?\nAnswer: 12:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 191}),
#  Document(page_content='Question: What time does the course 21259 Calculus in Three Dimensions end?\nAnswer: 01:50PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 192}),
#  Document(page_content='Question: What days does the course 21259 Calculus in Three Dimensions meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 193}),
#  Document(page_content='Question: What is the location of the course 21259 Calculus in Three Dimensions?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 194}),
#  Document(page_content='Question: What is the building and room number of the course 21259 Calculus in Three Dimensions?\nAnswer: DH 1212', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 195}),
#  Document(page_content='Question: How many units is the course 21259 Calculus in Three Dimensions?\nAnswer: 10.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 196}),
#  Document(page_content='Question: Who are the instructors of the course 21259 Calculus in Three Dimensions?\nAnswer: Johnson', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 197}),
#  Document(page_content='Question: What is the course number of Probability?\nAnswer: 21325', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 198}),
#  Document(page_content='Question: What is the name of course number 21325?\nAnswer: Probability', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 199}),
#  Document(page_content='Question: What time does the course 21325 Probability begin?\nAnswer: 12:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 200}),
#  Document(page_content='Question: What time does the course 21325 Probability end?\nAnswer: 01:50PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 201}),
#  Document(page_content='Question: What days does the course 21325 Probability meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 202}),
#  Document(page_content='Question: What is the location of the course 21325 Probability?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 203}),
#  Document(page_content='Question: What is the building and room number of the course 21325 Probability?\nAnswer: DH 1211', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 204}),
#  Document(page_content='Question: How many units is the course 21325 Probability?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 205}),
#  Document(page_content='Question: Who are the instructors of the course 21325 Probability?\nAnswer: Newman', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 206}),
#  Document(page_content='Question: What is the course number of Elementary French I?\nAnswer: 82101', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 207}),
#  Document(page_content='Question: What is the name of course number 82101?\nAnswer: Elementary French I', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 208}),
#  Document(page_content='Question: What time does the course 82101 Elementary French I begin?\nAnswer: 11:00AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 209}),
#  Document(page_content='Question: What time does the course 82101 Elementary French I end?\nAnswer: 12:20PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 210}),
#  Document(page_content='Question: What days does the course 82101 Elementary French I meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 211}),
#  Document(page_content='Question: What is the location of the course 82101 Elementary French I?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 212}),
#  Document(page_content='Question: What is the building and room number of the course 82101 Elementary French I?\nAnswer: PH 126A', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 213}),
#  Document(page_content='Question: How many units is the course 82101 Elementary French I?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 214}),
#  Document(page_content='Question: Who are the instructors of the course 82101 Elementary French I?\nAnswer: Instructor TBA', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 215}),
#  Document(page_content='Question: What is the course number of Elementary Japanese I?\nAnswer: 82171', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 216}),
#  Document(page_content='Question: What is the name of course number 82171?\nAnswer: Elementary Japanese I', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 217}),
#  Document(page_content='Question: What time does the course 82171 Elementary Japanese I begin?\nAnswer: 08:00AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 218}),
#  Document(page_content='Question: What time does the course 82171 Elementary Japanese I end?\nAnswer: 09:20AM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 219}),
#  Document(page_content='Question: What days does the course 82171 Elementary Japanese I meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 220}),
#  Document(page_content='Question: What is the location of the course 82171 Elementary Japanese I?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 221}),
#  Document(page_content='Question: What is the building and room number of the course 82171 Elementary Japanese I?\nAnswer: CMU REMOTE', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 222}),
#  Document(page_content='Question: How many units is the course 82171 Elementary Japanese I?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 223}),
#  Document(page_content='Question: Who are the instructors of the course 82171 Elementary Japanese I?\nAnswer: Zhan', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 224}),
#  Document(page_content='Question: What is the course number of Intermediate Japanese II?\nAnswer: 82272', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 225}),
#  Document(page_content='Question: What is the name of course number 82272?\nAnswer: Intermediate Japanese II', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 226}),
#  Document(page_content='Question: What time does the course 82272 Intermediate Japanese II begin?\nAnswer: 12:30PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 227}),
#  Document(page_content='Question: What time does the course 82272 Intermediate Japanese II end?\nAnswer: 01:50PM', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 228}),
#  Document(page_content='Question: What days does the course 82272 Intermediate Japanese II meet?\nAnswer: Monday, Tuesday, Wednesday, ThursdayFriday', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 229}),
#  Document(page_content='Question: What is the location of the course 82272 Intermediate Japanese II?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 230}),
#  Document(page_content='Question: What is the building and room number of the course 82272 Intermediate Japanese II?\nAnswer: PH 125B', metadata={'source': '../data/schedule_csv/sched_summer24_1_nl.csv', 'row': 231}),
# ...
#  Document(page_content='Question: What is the building and room number of the course 60398 Critical Studies: Social History of Animation?\nAnswer: CFA 303', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 411}),
#  Document(page_content='Question: How many units is the course 60398 Critical Studies: Social History of Animation?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 412}),
#  Document(page_content='Question: Who are the instructors of the course 60398 Critical Studies: Social History of Animation?\nAnswer: Duesing', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 413}),
#  Document(page_content='Question: What is the course number of Senior Studio?\nAnswer: 60402', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 414}),
#  Document(page_content='Question: What is the name of course number 60402?\nAnswer: Senior Studio', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 415}),
#  Document(page_content='Question: What time does the course 60402 Senior Studio begin?\nAnswer: 02:00PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 416}),
#  Document(page_content='Question: What time does the course 60402 Senior Studio end?\nAnswer: 04:50PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 417}),
#  Document(page_content='Question: What days does the course 60402 Senior Studio meet?\nAnswer: Tuesday, Thursday', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 418}),
#  Document(page_content='Question: What is the location of the course 60402 Senior Studio?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 419}),
#  Document(page_content='Question: What is the building and room number of the course 60402 Senior Studio?\nAnswer: CFA 303', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 420}),
#  Document(page_content='Question: How many units is the course 60402 Senior Studio?\nAnswer: 10.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 421}),
#  Document(page_content='Question: Who are the instructors of the course 60402 Senior Studio?\nAnswer: Hansen, Merrell', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 422}),
#  Document(page_content='Question: What is the course number of IDeATe: Experimental Sound Synthesis?\nAnswer: 60407', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 423}),
#  Document(page_content='Question: What is the name of course number 60407?\nAnswer: IDeATe: Experimental Sound Synthesis', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 424}),
#  Document(page_content='Question: What time does the course 60407 IDeATe: Experimental Sound Synthesis begin?\nAnswer: 12:00PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 425}),
#  Document(page_content='Question: What time does the course 60407 IDeATe: Experimental Sound Synthesis end?\nAnswer: 01:50PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 426}),
#  Document(page_content='Question: What days does the course 60407 IDeATe: Experimental Sound Synthesis meet?\nAnswer: Tuesday, Thursday', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 427}),
#  Document(page_content='Question: What is the location of the course 60407 IDeATe: Experimental Sound Synthesis?\nAnswer: A10A Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 428}),
#  Document(page_content='Question: What is the building and room number of the course 60407 IDeATe: Experimental Sound Synthesis?\nAnswer: HL', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 429}),
#  Document(page_content='Question: How many units is the course 60407 IDeATe: Experimental Sound Synthesis?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 430}),
#  Document(page_content='Question: Who are the instructors of the course 60407 IDeATe: Experimental Sound Synthesis?\nAnswer: Hsieh', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 431}),
#  Document(page_content='Question: What is the course number of Advanced SIS: Ceramics?\nAnswer: 60433', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 432}),
#  Document(page_content='Question: What is the name of course number 60433?\nAnswer: Advanced SIS: Ceramics', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 433}),
#  Document(page_content='Question: What time does the course 60433 Advanced SIS: Ceramics begin?\nAnswer: 02:00PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 434}),
#  Document(page_content='Question: What time does the course 60433 Advanced SIS: Ceramics end?\nAnswer: 04:50PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 435}),
#  Document(page_content='Question: What days does the course 60433 Advanced SIS: Ceramics meet?\nAnswer: Tuesday, Thursday', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 436}),
#  Document(page_content='Question: What is the location of the course 60433 Advanced SIS: Ceramics?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 437}),
#  Document(page_content='Question: What is the building and room number of the course 60433 Advanced SIS: Ceramics?\nAnswer: DH B301', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 438}),
#  Document(page_content='Question: How many units is the course 60433 Advanced SIS: Ceramics?\nAnswer: 10.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 439}),
#  Document(page_content='Question: Who are the instructors of the course 60433 Advanced SIS: Ceramics?\nAnswer: Sekino-Bove', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 440}),
#  Document(page_content='Question: What is the course number of Advanced DP3: Painting - Reverence And Representation?\nAnswer: 60457', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 441}),
#  Document(page_content='Question: What is the name of course number 60457?\nAnswer: Advanced DP3: Painting - Reverence And Representation', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 442}),
#  Document(page_content='Question: What time does the course 60457 Advanced DP3: Painting - Reverence And Representation begin?\nAnswer: 02:00PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 443}),
#  Document(page_content='Question: What time does the course 60457 Advanced DP3: Painting - Reverence And Representation end?\nAnswer: 04:50PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 444}),
#  Document(page_content='Question: What days does the course 60457 Advanced DP3: Painting - Reverence And Representation meet?\nAnswer: Monday, Wednesday,', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 445}),
#  Document(page_content='Question: What is the location of the course 60457 Advanced DP3: Painting - Reverence And Representation?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 446}),
#  Document(page_content='Question: What is the building and room number of the course 60457 Advanced DP3: Painting - Reverence And Representation?\nAnswer: CFA 415', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 447}),
#  Document(page_content='Question: How many units is the course 60457 Advanced DP3: Painting - Reverence And Representation?\nAnswer: 10.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 448}),
#  Document(page_content='Question: Who are the instructors of the course 60457 Advanced DP3: Painting - Reverence And Representation?\nAnswer: Henderson', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 449}),
#  Document(page_content='Question: What is the course number of M.F.A. Thesis Writing Seminar I?\nAnswer: 60711', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 450}),
#  Document(page_content='Question: What is the name of course number 60711?\nAnswer: M.F.A. Thesis Writing Seminar I', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 451}),
#  Document(page_content='Question: What time does the course 60711 M.F.A. Thesis Writing Seminar I begin?\nAnswer: 06:30PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 452}),
#  Document(page_content='Question: What time does the course 60711 M.F.A. Thesis Writing Seminar I end?\nAnswer: 09:20PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 453}),
#  Document(page_content='Question: What days does the course 60711 M.F.A. Thesis Writing Seminar I meet?\nAnswer: Monday,', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 454}),
#  Document(page_content='Question: What is the location of the course 60711 M.F.A. Thesis Writing Seminar I?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 455}),
#  Document(page_content='Question: What is the building and room number of the course 60711 M.F.A. Thesis Writing Seminar I?\nAnswer: HOA 323', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 456}),
#  Document(page_content='Question: How many units is the course 60711 M.F.A. Thesis Writing Seminar I?\nAnswer: 9.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 457}),
#  Document(page_content='Question: Who are the instructors of the course 60711 M.F.A. Thesis Writing Seminar I?\nAnswer: Dunn', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 458}),
#  Document(page_content='Question: What is the course number of M.F.A. Integrative Seminar?\nAnswer: 60791', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 459}),
#  Document(page_content='Question: What is the name of course number 60791?\nAnswer: M.F.A. Integrative Seminar', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 460}),
#  Document(page_content='Question: What time does the course 60791 M.F.A. Integrative Seminar begin?\nAnswer: 06:30PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 461}),
#  Document(page_content='Question: What time does the course 60791 M.F.A. Integrative Seminar end?\nAnswer: 09:20PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 462}),
#  Document(page_content='Question: What days does the course 60791 M.F.A. Integrative Seminar meet?\nAnswer: Wednesday,', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 463}),
#  Document(page_content='Question: What is the location of the course 60791 M.F.A. Integrative Seminar?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 464}),
#  Document(page_content='Question: What is the building and room number of the course 60791 M.F.A. Integrative Seminar?\nAnswer: HOA 322', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 465}),
#  Document(page_content='Question: How many units is the course 60791 M.F.A. Integrative Seminar?\nAnswer: 12.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 466}),
#  Document(page_content='Question: Who are the instructors of the course 60791 M.F.A. Integrative Seminar?\nAnswer: Wormsley', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 467}),
#  Document(page_content='Question: What is the course number of Exhibitions Management?\nAnswer: 93808', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 468}),
#  Document(page_content='Question: What is the name of course number 93808?\nAnswer: Exhibitions Management', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 469}),
#  Document(page_content='Question: What time does the course 93808 Exhibitions Management begin?\nAnswer: 09:30AM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 470}),
#  Document(page_content='Question: What time does the course 93808 Exhibitions Management end?\nAnswer: 10:50AM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 471}),
#  Document(page_content='Question: What days does the course 93808 Exhibitions Management meet?\nAnswer: Tuesday, Thursday', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 472}),
#  Document(page_content='Question: What is the location of the course 93808 Exhibitions Management?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 473}),
#  Document(page_content='Question: What is the building and room number of the course 93808 Exhibitions Management?\nAnswer: HBH 1006', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 474}),
#  Document(page_content='Question: How many units is the course 93808 Exhibitions Management?\nAnswer: 6.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 475}),
#  Document(page_content='Question: Who are the instructors of the course 93808 Exhibitions Management?\nAnswer: Gent', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 476}),
#  Document(page_content='Question: What is the course number of Audience Engagement and User-Experience Design?\nAnswer: 93815', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 477}),
#  Document(page_content='Question: What is the name of course number 93815?\nAnswer: Audience Engagement and User-Experience Design', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 478}),
#  Document(page_content='Question: What time does the course 93815 Audience Engagement and User-Experience Design begin?\nAnswer: 02:00PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 479}),
#  Document(page_content='Question: What time does the course 93815 Audience Engagement and User-Experience Design end?\nAnswer: 03:20PM', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 480}),
#  Document(page_content='Question: What days does the course 93815 Audience Engagement and User-Experience Design meet?\nAnswer: Tuesday, Thursday', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 481}),
#  Document(page_content='Question: What is the location of the course 93815 Audience Engagement and User-Experience Design?\nAnswer: Pittsburgh, Pennsylvania', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 482}),
#  Document(page_content='Question: What is the building and room number of the course 93815 Audience Engagement and User-Experience Design?\nAnswer: HBH 1202', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 483}),
#  Document(page_content='Question: How many units is the course 93815 Audience Engagement and User-Experience Design?\nAnswer: 6.0', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 484}),
#  Document(page_content='Question: Who are the instructors of the course 93815 Audience Engagement and User-Experience Design?\nAnswer: Crawford', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 485}),
#  Document(page_content='Question: What is the course number of External Relations: Fundraising & Individual Giving?\nAnswer: 93826', metadata={'source': '../data/schedule_csv/sched_spring24_nl.csv', 'row': 486}),
#  ...]

# %%
db_csv = create_db(docs_csv)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
db_csv.save_local("../faiss_index_schedule_csv")
